# %%
import os
import tensorflow as tf
import dask
import dask.array as da
import numpy as np

# %%
train_x = da.from_npy_stack('/home/skyolia/JupyterProjects/classification/cifar_10/data/train_x')
train_y = da.from_npy_stack('/home/skyolia/JupyterProjects/classification/cifar_10/data/train_y')
test_x = da.from_npy_stack('/home/skyolia/JupyterProjects/classification/cifar_10/data/test_x')
test_y = da.from_npy_stack('/home/skyolia/JupyterProjects/classification/cifar_10/data/test_y')
train_x, train_y, test_x, test_y
# Out:
# (dask.array<from-npy-stack, shape=(50000, 32, 32, 3), dtype=float64, chunksize=(10000, 32, 32, 3)>,
#  dask.array<from-npy-stack, shape=(50000, 1), dtype=float64, chunksize=(10000, 1)>,
#  dask.array<from-npy-stack, shape=(10000, 32, 32, 3), dtype=float64, chunksize=(1000, 32, 32, 3)>,
#  dask.array<from-npy-stack, shape=(10000, 1), dtype=float64, chunksize=(1000, 1)>)

# %%
class CIFAR10Sequence(tf.keras.utils.Sequence):

    def __init__(self, x, y, batch_size):
        self.x, self.y = x, y
        self.batch_size = batch_size

    def __len__(self):
        return int(np.ceil(len(self.x) / float(self.batch_size)))

    def __getitem__(self, idx):
        batch_x = self.x[idx * self.batch_size:(idx + 1) * self.batch_size]
        batch_y = self.y[idx * self.batch_size:(idx + 1) * self.batch_size]
        return batch_x, batch_y
        
class LRTensorBoard(tf.keras.callbacks.TensorBoard):
    '''
    Add learning rate evolution to Tensorboard
    '''
    def __init__(self, log_dir):
        super().__init__(log_dir=log_dir)

    def on_epoch_end(self, epoch, logs=None):
        logs['lr'] = tf.keras.backend.eval(self.model.optimizer.lr)
        super().on_epoch_end(epoch, logs)

def build_block(input_layer, filters, norm=True, k=[3,3]):
    layer = tf.keras.layers.Conv2D(filters, kernel_size=(k[0], k[1]), padding='same', use_bias=not norm, kernel_initializer='glorot_uniform')(input_layer)
    if norm:
        layer = tf.keras.layers.BatchNormalization()(layer)
    layer = tf.keras.layers.Activation('elu')(layer)
    return layer

def build_model(num_class):
    image_input = tf.keras.Input(shape=(32, 32, 3), name='input_layer')
    conv_1 = build_block(image_input, 48)
    conv_2 = build_block(conv_1, 48)
    pool_1 = tf.keras.layers.MaxPooling2D(padding='same')(conv_2)
    drop_1 = tf.keras.layers.Dropout(0.6)(pool_1)
    conv_3 = build_block(drop_1, 96)
    conv_4 = build_block(conv_3, 96)
    pool_2 = tf.keras.layers.MaxPooling2D(padding='same')(conv_4)
    drop_2 = tf.keras.layers.Dropout(0.6)(pool_2)
    conv_5 = build_block(drop_2, 192)
    conv_6 = build_block(conv_5, 192)
    pool_3 = tf.keras.layers.MaxPooling2D(padding='same')(conv_6)
    drop_3 = tf.keras.layers.Dropout(0.6)(pool_3)
    conv_7 = build_block(drop_3, 192, False, [1,1])
    drop_4 = tf.keras.layers.Dropout(0.25)(conv_7)
    gap = tf.keras.layers.GlobalAvgPool2D()(drop_4)
    logits = tf.keras.layers.Dense(units=num_class, activation='softmax', bias_initializer='ones', kernel_initializer='glorot_uniform')(gap)
    model = tf.keras.Model(inputs=image_input, outputs=logits)
    return model

# %%
model = build_model(10)
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer (InputLayer)     (None, 32, 32, 3)         0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 32, 32, 48)        1296
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32, 32, 48)        192
# _________________________________________________________________
# activation (Activation)      (None, 32, 32, 48)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 48)        20736
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 48)        192
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 48)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 48)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 16, 48)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 96)        41472
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16, 16, 96)        384
# _________________________________________________________________
# activation_2 (Activation)    (None, 16, 16, 96)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 96)        82944
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 16, 16, 96)        384
# _________________________________________________________________
# activation_3 (Activation)    (None, 16, 16, 96)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 96)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8, 8, 96)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 192)         165888
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 8, 8, 192)         768
# _________________________________________________________________
# activation_4 (Activation)    (None, 8, 8, 192)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 192)         331776
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 8, 8, 192)         768
# _________________________________________________________________
# activation_5 (Activation)    (None, 8, 8, 192)         0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 192)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 4, 192)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 4, 4, 192)         37056
# _________________________________________________________________
# activation_6 (Activation)    (None, 4, 4, 192)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 4, 4, 192)         0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 192)               0
# _________________________________________________________________
# dense (Dense)                (None, 10)                1930
# =================================================================
# Total params: 685,786
# Trainable params: 684,442
# Non-trainable params: 1,344
# _________________________________________________________________

# %%
epochs, lr, batch_size = 10000, 0.1, 256
steps_per_epoch = int(np.ceil(train_y.shape[0]/batch_size))
filepath="day_1.weights.best.hdf5"

train_generator = CIFAR10Sequence(train_x, train_y, batch_size)
test_generator = CIFAR10Sequence(test_x, test_y, batch_size)
tblr = LRTensorBoard(log_dir=os.getcwd())
checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.8, patience=10, min_lr=1e-10, mode='min')

sgd = tf.keras.optimizers.SGD(lr=lr, momentum=0.9)
model.compile(loss='sparse_categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

#model.load_weights(filepath)
model.fit_generator(generator=train_generator,
                    steps_per_epoch=steps_per_epoch,
                    epochs=epochs,
                    verbose=1,
                    validation_data=test_generator,
                    validation_steps=int(np.ceil(test_y.shape[0]/batch_size)),
                    use_multiprocessing=True,
                    workers=12,
                    shuffle=True,
                    #initial_epoch=461,
                    callbacks=[checkpoint, reduce_lr, tblr])
# Out:
# Epoch 1/10000
# 195/196 [============================>.] - ETA: 0s - loss: 1.8000 - acc: 0.3436
# Epoch 00001: val_acc improved from -inf to 0.27000, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 38s 192ms/step - loss: 1.7988 - acc: 0.3441 - val_loss: 2.1057 - val_acc: 0.2700
# Epoch 2/10000
# 195/196 [============================>.] - ETA: 0s - loss: 1.3836 - acc: 0.4922
# Epoch 00002: val_acc improved from 0.27000 to 0.50310, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 33s 168ms/step - loss: 1.3827 - acc: 0.4924 - val_loss: 1.3743 - val_acc: 0.5031
# Epoch 3/10000
# 195/196 [============================>.] - ETA: 0s - loss: 1.2131 - acc: 0.5607
# Epoch 00003: val_acc did not improve from 0.50310
# 196/196 [==============================] - 34s 175ms/step - loss: 1.2132 - acc: 0.5608 - val_loss: 1.5077 - val_acc: 0.4822
# Epoch 4/10000
# 195/196 [============================>.] - ETA: 0s - loss: 1.1111 - acc: 0.5993
# Epoch 00004: val_acc improved from 0.50310 to 0.62200, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 34s 174ms/step - loss: 1.1113 - acc: 0.5991 - val_loss: 1.0325 - val_acc: 0.6220
# Epoch 5/10000
# 195/196 [============================>.] - ETA: 0s - loss: 1.0465 - acc: 0.6236
# Epoch 00005: val_acc improved from 0.62200 to 0.64480, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 33s 167ms/step - loss: 1.0464 - acc: 0.6236 - val_loss: 0.9783 - val_acc: 0.6448
# Epoch 6/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.9933 - acc: 0.6453
# Epoch 00006: val_acc improved from 0.64480 to 0.67660, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 34s 172ms/step - loss: 0.9933 - acc: 0.6453 - val_loss: 0.9108 - val_acc: 0.6766
# Epoch 7/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.9539 - acc: 0.6598
# Epoch 00007: val_acc did not improve from 0.67660
# 196/196 [==============================] - 34s 172ms/step - loss: 0.9531 - acc: 0.6600 - val_loss: 0.9516 - val_acc: 0.6701
# Epoch 8/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.9228 - acc: 0.6703
# Epoch 00008: val_acc improved from 0.67660 to 0.70060, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 33s 170ms/step - loss: 0.9227 - acc: 0.6703 - val_loss: 0.8420 - val_acc: 0.7006
# Epoch 9/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.8825 - acc: 0.6845
# Epoch 00009: val_acc improved from 0.70060 to 0.70830, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 34s 171ms/step - loss: 0.8828 - acc: 0.6843 - val_loss: 0.8285 - val_acc: 0.7083
# Epoch 10/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.8580 - acc: 0.6950
# Epoch 00010: val_acc improved from 0.70830 to 0.70890, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 33s 170ms/step - loss: 0.8575 - acc: 0.6952 - val_loss: 0.8156 - val_acc: 0.7089
# Epoch 11/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.8224 - acc: 0.7067
# Epoch 00011: val_acc improved from 0.70890 to 0.72440, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 33s 170ms/step - loss: 0.8225 - acc: 0.7065 - val_loss: 0.7881 - val_acc: 0.7244
# Epoch 12/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.7962 - acc: 0.7175
# Epoch 00012: val_acc improved from 0.72440 to 0.73070, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 33s 170ms/step - loss: 0.7965 - acc: 0.7173 - val_loss: 0.7605 - val_acc: 0.7307
# Epoch 13/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.7788 - acc: 0.7234
# Epoch 00013: val_acc improved from 0.73070 to 0.74490, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 34s 171ms/step - loss: 0.7791 - acc: 0.7235 - val_loss: 0.7300 - val_acc: 0.7449
# Epoch 14/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.7509 - acc: 0.7345
# Epoch 00014: val_acc improved from 0.74490 to 0.75400, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 33s 170ms/step - loss: 0.7510 - acc: 0.7344 - val_loss: 0.7107 - val_acc: 0.7540
# Epoch 15/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.7379 - acc: 0.7399
# Epoch 00015: val_acc did not improve from 0.75400
# 196/196 [==============================] - 34s 171ms/step - loss: 0.7379 - acc: 0.7397 - val_loss: 0.7596 - val_acc: 0.7376
# Epoch 16/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.7206 - acc: 0.7451
# Epoch 00016: val_acc improved from 0.75400 to 0.77490, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 34s 171ms/step - loss: 0.7205 - acc: 0.7451 - val_loss: 0.6551 - val_acc: 0.7749
# Epoch 17/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.7055 - acc: 0.7482
# Epoch 00017: val_acc improved from 0.77490 to 0.77910, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 33s 170ms/step - loss: 0.7058 - acc: 0.7482 - val_loss: 0.6549 - val_acc: 0.7791
# Epoch 18/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.6894 - acc: 0.7568
# Epoch 00018: val_acc did not improve from 0.77910
# 196/196 [==============================] - 33s 171ms/step - loss: 0.6898 - acc: 0.7569 - val_loss: 0.6481 - val_acc: 0.7727
# Epoch 19/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.6682 - acc: 0.7651
# Epoch 00019: val_acc improved from 0.77910 to 0.79190, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 34s 171ms/step - loss: 0.6688 - acc: 0.7651 - val_loss: 0.6032 - val_acc: 0.7919
# Epoch 20/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.6645 - acc: 0.7670
# Epoch 00020: val_acc did not improve from 0.79190
# 196/196 [==============================] - 33s 171ms/step - loss: 0.6650 - acc: 0.7669 - val_loss: 0.6500 - val_acc: 0.7755
# Epoch 21/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.6424 - acc: 0.7717
# Epoch 00021: val_acc did not improve from 0.79190
# 196/196 [==============================] - 34s 171ms/step - loss: 0.6421 - acc: 0.7719 - val_loss: 0.6263 - val_acc: 0.7890
# Epoch 22/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.6337 - acc: 0.7766
# Epoch 00022: val_acc improved from 0.79190 to 0.80100, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 34s 171ms/step - loss: 0.6341 - acc: 0.7765 - val_loss: 0.5920 - val_acc: 0.8010
# Epoch 23/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.6248 - acc: 0.7787
# Epoch 00023: val_acc did not improve from 0.80100
# 196/196 [==============================] - 34s 171ms/step - loss: 0.6247 - acc: 0.7788 - val_loss: 0.6223 - val_acc: 0.7828
# Epoch 24/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.6143 - acc: 0.7842
# Epoch 00024: val_acc did not improve from 0.80100
# 196/196 [==============================] - 34s 171ms/step - loss: 0.6141 - acc: 0.7843 - val_loss: 0.5796 - val_acc: 0.8003
# Epoch 25/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.6123 - acc: 0.7842
# Epoch 00025: val_acc did not improve from 0.80100
# 196/196 [==============================] - 34s 171ms/step - loss: 0.6126 - acc: 0.7840 - val_loss: 0.5795 - val_acc: 0.8000
# Epoch 26/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.5958 - acc: 0.7903
# Epoch 00026: val_acc did not improve from 0.80100
# 196/196 [==============================] - 34s 171ms/step - loss: 0.5962 - acc: 0.7899 - val_loss: 0.6381 - val_acc: 0.7868
# Epoch 27/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.5833 - acc: 0.7949
# Epoch 00027: val_acc improved from 0.80100 to 0.81830, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 34s 171ms/step - loss: 0.5830 - acc: 0.7950 - val_loss: 0.5296 - val_acc: 0.8183
# Epoch 28/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.5752 - acc: 0.7969
# Epoch 00028: val_acc did not improve from 0.81830
# 196/196 [==============================] - 34s 172ms/step - loss: 0.5754 - acc: 0.7968 - val_loss: 0.6029 - val_acc: 0.7911
# Epoch 29/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.5699 - acc: 0.8003
# Epoch 00029: val_acc did not improve from 0.81830
# 196/196 [==============================] - 33s 170ms/step - loss: 0.5704 - acc: 0.8002 - val_loss: 0.5352 - val_acc: 0.8157
# Epoch 30/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.5614 - acc: 0.8031
# Epoch 00030: val_acc did not improve from 0.81830
# 196/196 [==============================] - 33s 171ms/step - loss: 0.5618 - acc: 0.8031 - val_loss: 0.5919 - val_acc: 0.8002
# Epoch 31/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.5556 - acc: 0.8059
# Epoch 00031: val_acc improved from 0.81830 to 0.81980, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 34s 172ms/step - loss: 0.5561 - acc: 0.8058 - val_loss: 0.5306 - val_acc: 0.8198
# Epoch 32/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.5406 - acc: 0.8109
# Epoch 00032: val_acc improved from 0.81980 to 0.82230, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 33s 171ms/step - loss: 0.5405 - acc: 0.8109 - val_loss: 0.5099 - val_acc: 0.8223
# Epoch 33/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.5385 - acc: 0.8083
# Epoch 00033: val_acc improved from 0.82230 to 0.82560, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 33s 171ms/step - loss: 0.5383 - acc: 0.8083 - val_loss: 0.5183 - val_acc: 0.8256
# Epoch 34/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.5301 - acc: 0.8133
# Epoch 00034: val_acc did not improve from 0.82560
# 196/196 [==============================] - 34s 172ms/step - loss: 0.5294 - acc: 0.8136 - val_loss: 0.5327 - val_acc: 0.8199
# Epoch 35/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.5254 - acc: 0.8155
# Epoch 00035: val_acc did not improve from 0.82560
# 196/196 [==============================] - 34s 173ms/step - loss: 0.5252 - acc: 0.8156 - val_loss: 0.5593 - val_acc: 0.8095
# Epoch 36/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.5260 - acc: 0.8153
# Epoch 00036: val_acc improved from 0.82560 to 0.82660, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 34s 171ms/step - loss: 0.5259 - acc: 0.8155 - val_loss: 0.5094 - val_acc: 0.8266
# Epoch 37/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.5156 - acc: 0.8193
# Epoch 00037: val_acc improved from 0.82660 to 0.83410, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 34s 173ms/step - loss: 0.5159 - acc: 0.8192 - val_loss: 0.4982 - val_acc: 0.8341
# Epoch 38/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.5055 - acc: 0.8237
# Epoch 00038: val_acc improved from 0.83410 to 0.83750, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 34s 172ms/step - loss: 0.5058 - acc: 0.8235 - val_loss: 0.4733 - val_acc: 0.8375
# Epoch 39/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.5044 - acc: 0.8244
# Epoch 00039: val_acc did not improve from 0.83750
# 196/196 [==============================] - 34s 172ms/step - loss: 0.5044 - acc: 0.8243 - val_loss: 0.5039 - val_acc: 0.8239
# Epoch 40/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.4919 - acc: 0.8277
# Epoch 00040: val_acc did not improve from 0.83750
# 196/196 [==============================] - 33s 170ms/step - loss: 0.4922 - acc: 0.8277 - val_loss: 0.4960 - val_acc: 0.8353
# Epoch 41/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.4963 - acc: 0.8254
# Epoch 00041: val_acc did not improve from 0.83750
# 196/196 [==============================] - 34s 172ms/step - loss: 0.4965 - acc: 0.8253 - val_loss: 0.4857 - val_acc: 0.8369
# Epoch 42/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.4855 - acc: 0.8295
# Epoch 00042: val_acc improved from 0.83750 to 0.83820, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 34s 174ms/step - loss: 0.4857 - acc: 0.8295 - val_loss: 0.4685 - val_acc: 0.8382
# Epoch 43/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.4785 - acc: 0.8318
# Epoch 00043: val_acc did not improve from 0.83820
# 196/196 [==============================] - 34s 171ms/step - loss: 0.4784 - acc: 0.8318 - val_loss: 0.5312 - val_acc: 0.8239
# Epoch 44/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.4714 - acc: 0.8351
# Epoch 00044: val_acc improved from 0.83820 to 0.84680, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 33s 170ms/step - loss: 0.4713 - acc: 0.8352 - val_loss: 0.4607 - val_acc: 0.8468
# Epoch 45/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.4668 - acc: 0.8356
# Epoch 00045: val_acc did not improve from 0.84680
# 196/196 [==============================] - 34s 173ms/step - loss: 0.4670 - acc: 0.8355 - val_loss: 0.5102 - val_acc: 0.8318
# Epoch 46/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.4642 - acc: 0.8360
# Epoch 00046: val_acc did not improve from 0.84680
# 196/196 [==============================] - 34s 174ms/step - loss: 0.4643 - acc: 0.8359 - val_loss: 0.4819 - val_acc: 0.8433
# Epoch 47/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.4549 - acc: 0.8377
# Epoch 00047: val_acc did not improve from 0.84680
# 196/196 [==============================] - 34s 173ms/step - loss: 0.4546 - acc: 0.8378 - val_loss: 0.4778 - val_acc: 0.8420
# Epoch 48/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.4511 - acc: 0.8421
# Epoch 00048: val_acc did not improve from 0.84680
# 196/196 [==============================] - 34s 174ms/step - loss: 0.4512 - acc: 0.8420 - val_loss: 0.5340 - val_acc: 0.8224
# Epoch 49/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.4573 - acc: 0.8407
# Epoch 00049: val_acc did not improve from 0.84680
# 196/196 [==============================] - 34s 173ms/step - loss: 0.4573 - acc: 0.8408 - val_loss: 0.4561 - val_acc: 0.8467
# Epoch 50/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.4481 - acc: 0.8421
# Epoch 00050: val_acc did not improve from 0.84680
# 196/196 [==============================] - 34s 173ms/step - loss: 0.4477 - acc: 0.8423 - val_loss: 0.4584 - val_acc: 0.8468
# Epoch 51/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.4470 - acc: 0.8422
# Epoch 00051: val_acc did not improve from 0.84680
# 196/196 [==============================] - 33s 171ms/step - loss: 0.4470 - acc: 0.8421 - val_loss: 0.5766 - val_acc: 0.8220
# Epoch 52/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.4399 - acc: 0.8449
# Epoch 00052: val_acc did not improve from 0.84680
# 196/196 [==============================] - 33s 170ms/step - loss: 0.4398 - acc: 0.8451 - val_loss: 0.4888 - val_acc: 0.8377
# Epoch 53/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.4344 - acc: 0.8483
# Epoch 00053: val_acc did not improve from 0.84680
# 196/196 [==============================] - 33s 171ms/step - loss: 0.4340 - acc: 0.8484 - val_loss: 0.4931 - val_acc: 0.8326
# Epoch 54/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.4253 - acc: 0.8513
# Epoch 00054: val_acc improved from 0.84680 to 0.85560, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 34s 172ms/step - loss: 0.4253 - acc: 0.8512 - val_loss: 0.4331 - val_acc: 0.8556
# Epoch 55/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.4258 - acc: 0.8503
# Epoch 00055: val_acc did not improve from 0.85560
# 196/196 [==============================] - 33s 169ms/step - loss: 0.4255 - acc: 0.8505 - val_loss: 0.4706 - val_acc: 0.8426
# Epoch 56/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.4209 - acc: 0.8523
# Epoch 00056: val_acc did not improve from 0.85560
# 196/196 [==============================] - 34s 171ms/step - loss: 0.4214 - acc: 0.8521 - val_loss: 0.5078 - val_acc: 0.8324
# Epoch 57/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.4160 - acc: 0.8529
# Epoch 00057: val_acc did not improve from 0.85560
# 196/196 [==============================] - 34s 172ms/step - loss: 0.4167 - acc: 0.8526 - val_loss: 0.4402 - val_acc: 0.8506
# Epoch 58/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.4096 - acc: 0.8554
# Epoch 00058: val_acc did not improve from 0.85560
# 196/196 [==============================] - 34s 173ms/step - loss: 0.4100 - acc: 0.8552 - val_loss: 0.5195 - val_acc: 0.8352
# Epoch 59/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.4108 - acc: 0.8537
# Epoch 00059: val_acc improved from 0.85560 to 0.85800, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 34s 172ms/step - loss: 0.4108 - acc: 0.8536 - val_loss: 0.4299 - val_acc: 0.8580
# Epoch 60/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.4066 - acc: 0.8563
# Epoch 00060: val_acc did not improve from 0.85800
# 196/196 [==============================] - 33s 168ms/step - loss: 0.4066 - acc: 0.8563 - val_loss: 0.4552 - val_acc: 0.8518
# Epoch 61/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.4038 - acc: 0.8572
# Epoch 00061: val_acc did not improve from 0.85800
# 196/196 [==============================] - 33s 168ms/step - loss: 0.4036 - acc: 0.8573 - val_loss: 0.4252 - val_acc: 0.8554
# Epoch 62/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.4010 - acc: 0.8573
# Epoch 00062: val_acc did not improve from 0.85800
# 196/196 [==============================] - 33s 168ms/step - loss: 0.4017 - acc: 0.8572 - val_loss: 0.4384 - val_acc: 0.8553
# Epoch 63/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.3993 - acc: 0.8595
# Epoch 00063: val_acc did not improve from 0.85800
# 196/196 [==============================] - 33s 167ms/step - loss: 0.3988 - acc: 0.8597 - val_loss: 0.4886 - val_acc: 0.8413
# Epoch 64/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.3945 - acc: 0.8605
# Epoch 00064: val_acc did not improve from 0.85800
# 196/196 [==============================] - 33s 168ms/step - loss: 0.3945 - acc: 0.8605 - val_loss: 0.4349 - val_acc: 0.8563
# Epoch 65/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.3896 - acc: 0.8626
# Epoch 00065: val_acc improved from 0.85800 to 0.86010, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 33s 168ms/step - loss: 0.3893 - acc: 0.8628 - val_loss: 0.4226 - val_acc: 0.8601
# Epoch 66/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.3919 - acc: 0.8632
# Epoch 00066: val_acc did not improve from 0.86010
# 196/196 [==============================] - 33s 171ms/step - loss: 0.3919 - acc: 0.8631 - val_loss: 0.4242 - val_acc: 0.8565
# Epoch 67/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.3863 - acc: 0.8628
# Epoch 00067: val_acc did not improve from 0.86010
# 196/196 [==============================] - 35s 177ms/step - loss: 0.3869 - acc: 0.8626 - val_loss: 0.4489 - val_acc: 0.8563
# Epoch 68/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.3837 - acc: 0.8649
# Epoch 00068: val_acc did not improve from 0.86010
# 196/196 [==============================] - 35s 178ms/step - loss: 0.3837 - acc: 0.8647 - val_loss: 0.4438 - val_acc: 0.8595
# Epoch 69/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.3780 - acc: 0.8659
# Epoch 00069: val_acc did not improve from 0.86010
# 196/196 [==============================] - 33s 170ms/step - loss: 0.3781 - acc: 0.8659 - val_loss: 0.4464 - val_acc: 0.8565
# Epoch 70/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.3756 - acc: 0.8673
# Epoch 00070: val_acc improved from 0.86010 to 0.86070, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 34s 173ms/step - loss: 0.3751 - acc: 0.8675 - val_loss: 0.4364 - val_acc: 0.8607
# Epoch 71/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.3739 - acc: 0.8668
# Epoch 00071: val_acc did not improve from 0.86070
# 196/196 [==============================] - 34s 172ms/step - loss: 0.3737 - acc: 0.8668 - val_loss: 0.4775 - val_acc: 0.8470
# Epoch 72/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.3692 - acc: 0.8700
# Epoch 00072: val_acc did not improve from 0.86070
# 196/196 [==============================] - 34s 176ms/step - loss: 0.3687 - acc: 0.8702 - val_loss: 0.4363 - val_acc: 0.8599
# Epoch 73/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.3726 - acc: 0.8681
# Epoch 00073: val_acc did not improve from 0.86070
# 196/196 [==============================] - 33s 169ms/step - loss: 0.3725 - acc: 0.8682 - val_loss: 0.4476 - val_acc: 0.8527
# Epoch 74/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.3653 - acc: 0.8707
# Epoch 00074: val_acc improved from 0.86070 to 0.86830, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 33s 171ms/step - loss: 0.3654 - acc: 0.8706 - val_loss: 0.4149 - val_acc: 0.8683
# Epoch 75/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.3633 - acc: 0.8695
# Epoch 00075: val_acc did not improve from 0.86830
# 196/196 [==============================] - 33s 171ms/step - loss: 0.3631 - acc: 0.8696 - val_loss: 0.4694 - val_acc: 0.8497
# Epoch 76/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.3634 - acc: 0.8720
# Epoch 00076: val_acc did not improve from 0.86830
# 196/196 [==============================] - 34s 172ms/step - loss: 0.3630 - acc: 0.8721 - val_loss: 0.4187 - val_acc: 0.8636
# Epoch 77/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.3569 - acc: 0.8735
# Epoch 00077: val_acc did not improve from 0.86830
# 196/196 [==============================] - 34s 171ms/step - loss: 0.3568 - acc: 0.8735 - val_loss: 0.4262 - val_acc: 0.8631
# Epoch 78/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.3575 - acc: 0.8740
# Epoch 00078: val_acc did not improve from 0.86830
# 196/196 [==============================] - 34s 174ms/step - loss: 0.3574 - acc: 0.8740 - val_loss: 0.4386 - val_acc: 0.8614
# Epoch 79/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.3489 - acc: 0.8765
# Epoch 00079: val_acc improved from 0.86830 to 0.87050, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 33s 171ms/step - loss: 0.3491 - acc: 0.8765 - val_loss: 0.4014 - val_acc: 0.8705
# Epoch 80/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.3476 - acc: 0.8766
# Epoch 00080: val_acc did not improve from 0.87050
# 196/196 [==============================] - 34s 174ms/step - loss: 0.3474 - acc: 0.8767 - val_loss: 0.4410 - val_acc: 0.8557
# Epoch 81/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.3485 - acc: 0.8770
# Epoch 00081: val_acc did not improve from 0.87050
# 196/196 [==============================] - 35s 178ms/step - loss: 0.3480 - acc: 0.8772 - val_loss: 0.3976 - val_acc: 0.8694
# Epoch 82/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.3488 - acc: 0.8757
# Epoch 00082: val_acc did not improve from 0.87050
# 196/196 [==============================] - 34s 174ms/step - loss: 0.3486 - acc: 0.8759 - val_loss: 0.4113 - val_acc: 0.8682
# Epoch 83/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.3445 - acc: 0.8792
# Epoch 00083: val_acc improved from 0.87050 to 0.87170, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 34s 173ms/step - loss: 0.3444 - acc: 0.8792 - val_loss: 0.4017 - val_acc: 0.8717
# Epoch 84/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.3403 - acc: 0.8786
# Epoch 00084: val_acc did not improve from 0.87170
# 196/196 [==============================] - 33s 171ms/step - loss: 0.3404 - acc: 0.8786 - val_loss: 0.4569 - val_acc: 0.8541
# Epoch 85/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.3359 - acc: 0.8809
# Epoch 00085: val_acc improved from 0.87170 to 0.87400, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 33s 170ms/step - loss: 0.3362 - acc: 0.8808 - val_loss: 0.3850 - val_acc: 0.8740
# Epoch 86/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.3308 - acc: 0.8818
# Epoch 00086: val_acc did not improve from 0.87400
# 196/196 [==============================] - 34s 171ms/step - loss: 0.3306 - acc: 0.8819 - val_loss: 0.4291 - val_acc: 0.8594
# Epoch 87/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.3384 - acc: 0.8818
# Epoch 00087: val_acc did not improve from 0.87400
# 196/196 [==============================] - 34s 173ms/step - loss: 0.3382 - acc: 0.8820 - val_loss: 0.3995 - val_acc: 0.8692
# Epoch 88/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.3318 - acc: 0.8818
# Epoch 00088: val_acc did not improve from 0.87400
# 196/196 [==============================] - 34s 176ms/step - loss: 0.3321 - acc: 0.8817 - val_loss: 0.4035 - val_acc: 0.8715
# Epoch 89/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.3315 - acc: 0.8830
# Epoch 00089: val_acc did not improve from 0.87400
# 196/196 [==============================] - 34s 174ms/step - loss: 0.3318 - acc: 0.8829 - val_loss: 0.4166 - val_acc: 0.8668
# Epoch 90/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.3289 - acc: 0.8836
# Epoch 00090: val_acc did not improve from 0.87400
# 196/196 [==============================] - 34s 175ms/step - loss: 0.3292 - acc: 0.8833 - val_loss: 0.4022 - val_acc: 0.8723
# Epoch 91/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.3238 - acc: 0.8847
# Epoch 00091: val_acc did not improve from 0.87400
# 196/196 [==============================] - 34s 174ms/step - loss: 0.3236 - acc: 0.8848 - val_loss: 0.4065 - val_acc: 0.8730
# Epoch 92/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.3266 - acc: 0.8846
# Epoch 00092: val_acc did not improve from 0.87400
# 196/196 [==============================] - 34s 174ms/step - loss: 0.3262 - acc: 0.8848 - val_loss: 0.4261 - val_acc: 0.8668
# Epoch 93/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.3213 - acc: 0.8861
# Epoch 00093: val_acc did not improve from 0.87400
# 196/196 [==============================] - 34s 171ms/step - loss: 0.3215 - acc: 0.8861 - val_loss: 0.5663 - val_acc: 0.8257
# Epoch 94/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.3238 - acc: 0.8850
# Epoch 00094: val_acc did not improve from 0.87400
# 196/196 [==============================] - 33s 167ms/step - loss: 0.3236 - acc: 0.8850 - val_loss: 0.4018 - val_acc: 0.8737
# Epoch 95/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.3215 - acc: 0.8866
# Epoch 00095: val_acc did not improve from 0.87400
# 196/196 [==============================] - 33s 168ms/step - loss: 0.3214 - acc: 0.8867 - val_loss: 0.4034 - val_acc: 0.8717
# Epoch 96/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.3064 - acc: 0.8911
# Epoch 00096: val_acc did not improve from 0.87400
# 196/196 [==============================] - 34s 172ms/step - loss: 0.3063 - acc: 0.8911 - val_loss: 0.3920 - val_acc: 0.8737
# Epoch 97/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.3041 - acc: 0.8916
# Epoch 00097: val_acc did not improve from 0.87400
# 196/196 [==============================] - 33s 170ms/step - loss: 0.3043 - acc: 0.8914 - val_loss: 0.4330 - val_acc: 0.8672
# Epoch 98/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.3013 - acc: 0.8913
# Epoch 00098: val_acc improved from 0.87400 to 0.87560, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 34s 173ms/step - loss: 0.3010 - acc: 0.8913 - val_loss: 0.4014 - val_acc: 0.8756
# Epoch 99/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2968 - acc: 0.8932
# Epoch 00099: val_acc did not improve from 0.87560
# 196/196 [==============================] - 34s 172ms/step - loss: 0.2972 - acc: 0.8930 - val_loss: 0.4166 - val_acc: 0.8723
# Epoch 100/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2992 - acc: 0.8950
# Epoch 00100: val_acc did not improve from 0.87560
# 196/196 [==============================] - 34s 173ms/step - loss: 0.2991 - acc: 0.8950 - val_loss: 0.4002 - val_acc: 0.8740
# Epoch 101/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2945 - acc: 0.8952
# Epoch 00101: val_acc did not improve from 0.87560
# 196/196 [==============================] - 35s 177ms/step - loss: 0.2946 - acc: 0.8953 - val_loss: 0.3849 - val_acc: 0.8752
# Epoch 102/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2875 - acc: 0.8976
# Epoch 00102: val_acc improved from 0.87560 to 0.87790, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 35s 177ms/step - loss: 0.2878 - acc: 0.8975 - val_loss: 0.3923 - val_acc: 0.8779
# Epoch 103/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2919 - acc: 0.8948
# Epoch 00103: val_acc did not improve from 0.87790
# 196/196 [==============================] - 34s 175ms/step - loss: 0.2924 - acc: 0.8946 - val_loss: 0.3972 - val_acc: 0.8745
# Epoch 104/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2895 - acc: 0.8974
# Epoch 00104: val_acc did not improve from 0.87790
# 196/196 [==============================] - 34s 174ms/step - loss: 0.2893 - acc: 0.8976 - val_loss: 0.4378 - val_acc: 0.8625
# Epoch 105/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2887 - acc: 0.8981
# Epoch 00105: val_acc did not improve from 0.87790
# 196/196 [==============================] - 33s 169ms/step - loss: 0.2889 - acc: 0.8980 - val_loss: 0.3901 - val_acc: 0.8779
# Epoch 106/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2774 - acc: 0.9023
# Epoch 00106: val_acc did not improve from 0.87790
# 196/196 [==============================] - 33s 168ms/step - loss: 0.2771 - acc: 0.9024 - val_loss: 0.4143 - val_acc: 0.8717
# Epoch 107/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2727 - acc: 0.9030
# Epoch 00107: val_acc improved from 0.87790 to 0.88410, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 33s 168ms/step - loss: 0.2732 - acc: 0.9028 - val_loss: 0.3692 - val_acc: 0.8841
# Epoch 108/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2731 - acc: 0.9033
# Epoch 00108: val_acc did not improve from 0.88410
# 196/196 [==============================] - 33s 168ms/step - loss: 0.2731 - acc: 0.9033 - val_loss: 0.4106 - val_acc: 0.8767
# Epoch 109/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2708 - acc: 0.9026
# Epoch 00109: val_acc did not improve from 0.88410
# 196/196 [==============================] - 33s 168ms/step - loss: 0.2709 - acc: 0.9027 - val_loss: 0.3741 - val_acc: 0.8806
# Epoch 110/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2745 - acc: 0.9006
# Epoch 00110: val_acc did not improve from 0.88410
# 196/196 [==============================] - 33s 169ms/step - loss: 0.2746 - acc: 0.9006 - val_loss: 0.4409 - val_acc: 0.8660
# Epoch 111/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2733 - acc: 0.9027
# Epoch 00111: val_acc did not improve from 0.88410
# 196/196 [==============================] - 33s 169ms/step - loss: 0.2731 - acc: 0.9028 - val_loss: 0.4292 - val_acc: 0.8674
# Epoch 112/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2679 - acc: 0.9046
# Epoch 00112: val_acc did not improve from 0.88410
# 196/196 [==============================] - 33s 169ms/step - loss: 0.2679 - acc: 0.9046 - val_loss: 0.4036 - val_acc: 0.8776
# Epoch 113/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2667 - acc: 0.9047
# Epoch 00113: val_acc did not improve from 0.88410
# 196/196 [==============================] - 33s 169ms/step - loss: 0.2666 - acc: 0.9048 - val_loss: 0.3846 - val_acc: 0.8833
# Epoch 114/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2698 - acc: 0.9038
# Epoch 00114: val_acc did not improve from 0.88410
# 196/196 [==============================] - 33s 169ms/step - loss: 0.2697 - acc: 0.9038 - val_loss: 0.3890 - val_acc: 0.8815
# Epoch 115/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2641 - acc: 0.9061
# Epoch 00115: val_acc did not improve from 0.88410
# 196/196 [==============================] - 33s 169ms/step - loss: 0.2640 - acc: 0.9061 - val_loss: 0.4326 - val_acc: 0.8629
# Epoch 116/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2670 - acc: 0.9049
# Epoch 00116: val_acc did not improve from 0.88410
# 196/196 [==============================] - 33s 168ms/step - loss: 0.2672 - acc: 0.9049 - val_loss: 0.3929 - val_acc: 0.8775
# Epoch 117/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2651 - acc: 0.9049
# Epoch 00117: val_acc did not improve from 0.88410
# 196/196 [==============================] - 33s 169ms/step - loss: 0.2650 - acc: 0.9049 - val_loss: 0.4042 - val_acc: 0.8726
# Epoch 118/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2542 - acc: 0.9100
# Epoch 00118: val_acc did not improve from 0.88410
# 196/196 [==============================] - 34s 173ms/step - loss: 0.2541 - acc: 0.9100 - val_loss: 0.4587 - val_acc: 0.8686
# Epoch 119/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2544 - acc: 0.9098
# Epoch 00119: val_acc did not improve from 0.88410
# 196/196 [==============================] - 34s 172ms/step - loss: 0.2544 - acc: 0.9097 - val_loss: 0.3839 - val_acc: 0.8813
# Epoch 120/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2523 - acc: 0.9091
# Epoch 00120: val_acc improved from 0.88410 to 0.88990, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 33s 171ms/step - loss: 0.2523 - acc: 0.9091 - val_loss: 0.3626 - val_acc: 0.8899
# Epoch 121/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2476 - acc: 0.9132
# Epoch 00121: val_acc did not improve from 0.88990
# 196/196 [==============================] - 35s 178ms/step - loss: 0.2478 - acc: 0.9129 - val_loss: 0.3844 - val_acc: 0.8823
# Epoch 122/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2465 - acc: 0.9121
# Epoch 00122: val_acc did not improve from 0.88990
# 196/196 [==============================] - 35s 177ms/step - loss: 0.2465 - acc: 0.9121 - val_loss: 0.3975 - val_acc: 0.8769
# Epoch 123/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2455 - acc: 0.9112
# Epoch 00123: val_acc did not improve from 0.88990
# 196/196 [==============================] - 35s 176ms/step - loss: 0.2454 - acc: 0.9113 - val_loss: 0.4233 - val_acc: 0.8782
# Epoch 124/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2490 - acc: 0.9112
# Epoch 00124: val_acc did not improve from 0.88990
# 196/196 [==============================] - 35s 178ms/step - loss: 0.2497 - acc: 0.9110 - val_loss: 0.3723 - val_acc: 0.8821
# Epoch 125/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2449 - acc: 0.9125
# Epoch 00125: val_acc did not improve from 0.88990
# 196/196 [==============================] - 34s 173ms/step - loss: 0.2450 - acc: 0.9125 - val_loss: 0.3790 - val_acc: 0.8852
# Epoch 126/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2408 - acc: 0.9144
# Epoch 00126: val_acc did not improve from 0.88990
# 196/196 [==============================] - 34s 172ms/step - loss: 0.2408 - acc: 0.9143 - val_loss: 0.3908 - val_acc: 0.8815
# Epoch 127/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2445 - acc: 0.9128
# Epoch 00127: val_acc did not improve from 0.88990
# 196/196 [==============================] - 33s 169ms/step - loss: 0.2444 - acc: 0.9129 - val_loss: 0.3706 - val_acc: 0.8832
# Epoch 128/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2461 - acc: 0.9127
# Epoch 00128: val_acc did not improve from 0.88990
# 196/196 [==============================] - 34s 174ms/step - loss: 0.2460 - acc: 0.9127 - val_loss: 0.4005 - val_acc: 0.8772
# Epoch 129/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2453 - acc: 0.9108
# Epoch 00129: val_acc did not improve from 0.88990
# 196/196 [==============================] - 34s 172ms/step - loss: 0.2453 - acc: 0.9108 - val_loss: 0.3770 - val_acc: 0.8828
# Epoch 130/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2365 - acc: 0.9143
# Epoch 00130: val_acc did not improve from 0.88990
# 196/196 [==============================] - 34s 171ms/step - loss: 0.2368 - acc: 0.9142 - val_loss: 0.4422 - val_acc: 0.8722
# Epoch 131/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2366 - acc: 0.9148
# Epoch 00131: val_acc did not improve from 0.88990
# 196/196 [==============================] - 33s 171ms/step - loss: 0.2365 - acc: 0.9148 - val_loss: 0.3837 - val_acc: 0.8832
# Epoch 132/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2325 - acc: 0.9159
# Epoch 00132: val_acc did not improve from 0.88990
# 196/196 [==============================] - 35s 176ms/step - loss: 0.2323 - acc: 0.9159 - val_loss: 0.3844 - val_acc: 0.8834
# Epoch 133/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2331 - acc: 0.9156
# Epoch 00133: val_acc did not improve from 0.88990
# 196/196 [==============================] - 34s 173ms/step - loss: 0.2334 - acc: 0.9154 - val_loss: 0.4437 - val_acc: 0.8709
# Epoch 134/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2300 - acc: 0.9168
# Epoch 00134: val_acc did not improve from 0.88990
# 196/196 [==============================] - 34s 176ms/step - loss: 0.2299 - acc: 0.9168 - val_loss: 0.3790 - val_acc: 0.8864
# Epoch 135/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2281 - acc: 0.9178
# Epoch 00135: val_acc did not improve from 0.88990
# 196/196 [==============================] - 34s 172ms/step - loss: 0.2284 - acc: 0.9177 - val_loss: 0.3884 - val_acc: 0.8847
# Epoch 136/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2305 - acc: 0.9163
# Epoch 00136: val_acc did not improve from 0.88990
# 196/196 [==============================] - 33s 168ms/step - loss: 0.2303 - acc: 0.9163 - val_loss: 0.3749 - val_acc: 0.8854
# Epoch 137/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2297 - acc: 0.9170
# Epoch 00137: val_acc did not improve from 0.88990
# 196/196 [==============================] - 33s 168ms/step - loss: 0.2295 - acc: 0.9170 - val_loss: 0.3866 - val_acc: 0.8854
# Epoch 138/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2289 - acc: 0.9176
# Epoch 00138: val_acc did not improve from 0.88990
# 196/196 [==============================] - 33s 168ms/step - loss: 0.2289 - acc: 0.9175 - val_loss: 0.4013 - val_acc: 0.8788
# Epoch 139/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2249 - acc: 0.9190
# Epoch 00139: val_acc did not improve from 0.88990
# 196/196 [==============================] - 33s 167ms/step - loss: 0.2250 - acc: 0.9190 - val_loss: 0.3699 - val_acc: 0.8881
# Epoch 140/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2290 - acc: 0.9175
# Epoch 00140: val_acc did not improve from 0.88990
# 196/196 [==============================] - 33s 168ms/step - loss: 0.2288 - acc: 0.9176 - val_loss: 0.3632 - val_acc: 0.8891
# Epoch 141/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2243 - acc: 0.9202
# Epoch 00141: val_acc did not improve from 0.88990
# 196/196 [==============================] - 33s 169ms/step - loss: 0.2243 - acc: 0.9201 - val_loss: 0.3795 - val_acc: 0.8861
# Epoch 142/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2176 - acc: 0.9207
# Epoch 00142: val_acc did not improve from 0.88990
# 196/196 [==============================] - 34s 171ms/step - loss: 0.2177 - acc: 0.9207 - val_loss: 0.3845 - val_acc: 0.8851
# Epoch 143/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2177 - acc: 0.9215
# Epoch 00143: val_acc did not improve from 0.88990
# 196/196 [==============================] - 34s 174ms/step - loss: 0.2176 - acc: 0.9216 - val_loss: 0.3917 - val_acc: 0.8841
# Epoch 144/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2162 - acc: 0.9225
# Epoch 00144: val_acc did not improve from 0.88990
# 196/196 [==============================] - 33s 169ms/step - loss: 0.2162 - acc: 0.9224 - val_loss: 0.3726 - val_acc: 0.8869
# Epoch 145/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2194 - acc: 0.9216
# Epoch 00145: val_acc did not improve from 0.88990
# 196/196 [==============================] - 33s 171ms/step - loss: 0.2193 - acc: 0.9216 - val_loss: 0.4026 - val_acc: 0.8825
# Epoch 146/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2151 - acc: 0.9224
# Epoch 00146: val_acc did not improve from 0.88990
# 196/196 [==============================] - 33s 168ms/step - loss: 0.2150 - acc: 0.9224 - val_loss: 0.3752 - val_acc: 0.8879
# Epoch 147/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2140 - acc: 0.9239
# Epoch 00147: val_acc did not improve from 0.88990
# 196/196 [==============================] - 33s 168ms/step - loss: 0.2142 - acc: 0.9238 - val_loss: 0.3909 - val_acc: 0.8847
# Epoch 148/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2170 - acc: 0.9219
# Epoch 00148: val_acc did not improve from 0.88990
# 196/196 [==============================] - 33s 167ms/step - loss: 0.2171 - acc: 0.9218 - val_loss: 0.3809 - val_acc: 0.8894
# Epoch 149/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2127 - acc: 0.9236
# Epoch 00149: val_acc improved from 0.88990 to 0.89010, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 33s 171ms/step - loss: 0.2125 - acc: 0.9237 - val_loss: 0.3800 - val_acc: 0.8901
# Epoch 150/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2130 - acc: 0.9234
# Epoch 00150: val_acc did not improve from 0.89010
# 196/196 [==============================] - 33s 168ms/step - loss: 0.2130 - acc: 0.9234 - val_loss: 0.4156 - val_acc: 0.8806
# Epoch 151/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2099 - acc: 0.9252
# Epoch 00151: val_acc improved from 0.89010 to 0.89400, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 33s 168ms/step - loss: 0.2101 - acc: 0.9251 - val_loss: 0.3618 - val_acc: 0.8940
# Epoch 152/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2092 - acc: 0.9243
# Epoch 00152: val_acc did not improve from 0.89400
# 196/196 [==============================] - 33s 168ms/step - loss: 0.2090 - acc: 0.9243 - val_loss: 0.3900 - val_acc: 0.8886
# Epoch 153/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2072 - acc: 0.9248
# Epoch 00153: val_acc did not improve from 0.89400
# 196/196 [==============================] - 33s 168ms/step - loss: 0.2074 - acc: 0.9247 - val_loss: 0.3845 - val_acc: 0.8897
# Epoch 154/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2090 - acc: 0.9248
# Epoch 00154: val_acc did not improve from 0.89400
# 196/196 [==============================] - 34s 171ms/step - loss: 0.2092 - acc: 0.9247 - val_loss: 0.3835 - val_acc: 0.8880
# Epoch 155/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2056 - acc: 0.9250
# Epoch 00155: val_acc did not improve from 0.89400
# 196/196 [==============================] - 33s 170ms/step - loss: 0.2055 - acc: 0.9251 - val_loss: 0.3822 - val_acc: 0.8851
# Epoch 156/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2063 - acc: 0.9251
# Epoch 00156: val_acc did not improve from 0.89400
# 196/196 [==============================] - 33s 168ms/step - loss: 0.2063 - acc: 0.9251 - val_loss: 0.3836 - val_acc: 0.8890
# Epoch 157/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2056 - acc: 0.9260
# Epoch 00157: val_acc did not improve from 0.89400
# 196/196 [==============================] - 33s 167ms/step - loss: 0.2056 - acc: 0.9260 - val_loss: 0.3820 - val_acc: 0.8852
# Epoch 158/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2033 - acc: 0.9267
# Epoch 00158: val_acc did not improve from 0.89400
# 196/196 [==============================] - 33s 168ms/step - loss: 0.2032 - acc: 0.9268 - val_loss: 0.3840 - val_acc: 0.8885
# Epoch 159/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2055 - acc: 0.9272
# Epoch 00159: val_acc did not improve from 0.89400
# 196/196 [==============================] - 33s 168ms/step - loss: 0.2058 - acc: 0.9271 - val_loss: 0.4086 - val_acc: 0.8826
# Epoch 160/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.1980 - acc: 0.9287
# Epoch 00160: val_acc did not improve from 0.89400
# 196/196 [==============================] - 33s 168ms/step - loss: 0.1981 - acc: 0.9287 - val_loss: 0.3503 - val_acc: 0.8930
# Epoch 161/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2032 - acc: 0.9269
# Epoch 00161: val_acc did not improve from 0.89400
# 196/196 [==============================] - 33s 168ms/step - loss: 0.2033 - acc: 0.9268 - val_loss: 0.3661 - val_acc: 0.8909
# Epoch 162/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2047 - acc: 0.9267
# Epoch 00162: val_acc did not improve from 0.89400
# 196/196 [==============================] - 33s 167ms/step - loss: 0.2047 - acc: 0.9266 - val_loss: 0.4026 - val_acc: 0.8854
# Epoch 163/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2029 - acc: 0.9270
# Epoch 00163: val_acc did not improve from 0.89400
# 196/196 [==============================] - 33s 168ms/step - loss: 0.2029 - acc: 0.9270 - val_loss: 0.3833 - val_acc: 0.8865
# Epoch 164/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2013 - acc: 0.9280
# Epoch 00164: val_acc did not improve from 0.89400
# 196/196 [==============================] - 33s 168ms/step - loss: 0.2011 - acc: 0.9281 - val_loss: 0.3870 - val_acc: 0.8883
# Epoch 165/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2048 - acc: 0.9254
# Epoch 00165: val_acc did not improve from 0.89400
# 196/196 [==============================] - 33s 168ms/step - loss: 0.2045 - acc: 0.9256 - val_loss: 0.3932 - val_acc: 0.8877
# Epoch 166/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2029 - acc: 0.9270
# Epoch 00166: val_acc did not improve from 0.89400
# 196/196 [==============================] - 33s 168ms/step - loss: 0.2032 - acc: 0.9270 - val_loss: 0.3806 - val_acc: 0.8881
# Epoch 167/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2027 - acc: 0.9272
# Epoch 00167: val_acc did not improve from 0.89400
# 196/196 [==============================] - 33s 168ms/step - loss: 0.2026 - acc: 0.9271 - val_loss: 0.3719 - val_acc: 0.8923
# Epoch 168/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.1978 - acc: 0.9292
# Epoch 00168: val_acc did not improve from 0.89400
# 196/196 [==============================] - 33s 167ms/step - loss: 0.1979 - acc: 0.9293 - val_loss: 0.3653 - val_acc: 0.8903
# Epoch 169/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.1974 - acc: 0.9286
# Epoch 00169: val_acc did not improve from 0.89400
# 196/196 [==============================] - 33s 167ms/step - loss: 0.1976 - acc: 0.9285 - val_loss: 0.3829 - val_acc: 0.8916
# Epoch 170/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2003 - acc: 0.9283
# Epoch 00170: val_acc did not improve from 0.89400
# 196/196 [==============================] - 33s 168ms/step - loss: 0.2003 - acc: 0.9282 - val_loss: 0.3696 - val_acc: 0.8907
# Epoch 171/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.1975 - acc: 0.9290
# Epoch 00171: val_acc did not improve from 0.89400
# 196/196 [==============================] - 33s 168ms/step - loss: 0.1971 - acc: 0.9291 - val_loss: 0.3664 - val_acc: 0.8928
# Epoch 172/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.1982 - acc: 0.9279
# Epoch 00172: val_acc did not improve from 0.89400
# ...
#     self.run()
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/multiprocessing/queues.py", line 335, in get
#     res = self._reader.recv_bytes()
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# Traceback (most recent call last):
# Traceback (most recent call last):
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/site-packages/tensorflow/python/keras/engine/training_generator.py", line 171, in fit_generator
#     x, y, sample_weight=sample_weight, class_weight=class_weight)
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py", line 1828, in train_on_batch
#     outputs = self.train_function(ins)
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/site-packages/tensorflow/python/keras/backend.py", line 2978, in __call__
#     run_metadata=self.run_metadata)
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 1399, in __call__
#     run_metadata_ptr)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3267, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-5-88a507e358c5>", line 25, in <module>
#     callbacks=[checkpoint, reduce_lr, tblr])
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py", line 2065, in fit_generator
#     initial_epoch=initial_epoch)
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/site-packages/tensorflow/python/keras/engine/training_generator.py", line 219, in fit_generator
#     enqueuer.stop()
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/site-packages/tensorflow/python/keras/utils/data_utils.py", line 633, in stop
#     self.run_thread.join(timeout)
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/threading.py", line 1056, in join
#     self._wait_for_tstate_lock()
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/threading.py", line 1072, in _wait_for_tstate_lock
#     elif lock.acquire(block, timeout):
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2018, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1095, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 313, in wrapped
#     return f(*args, **kwargs)
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 347, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/inspect.py", line 1488, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/inspect.py", line 1446, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/inspect.py", line 742, in getmodule
#     os.path.realpath(f)] = module.__name__
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/posixpath.py", line 388, in realpath
#     path, ok = _joinrealpath(filename[:0], filename, {})
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/posixpath.py", line 422, in _joinrealpath
#     if not islink(newpath):
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/posixpath.py", line 171, in islink
#     st = os.lstat(path)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/site-packages/tensorflow/python/keras/engine/training_generator.py", line 171, in fit_generator
#     x, y, sample_weight=sample_weight, class_weight=class_weight)
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py", line 1828, in train_on_batch
#     outputs = self.train_function(ins)
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/site-packages/tensorflow/python/keras/backend.py", line 2978, in __call__
#     run_metadata=self.run_metadata)
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 1399, in __call__
#     run_metadata_ptr)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3267, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-5-88a507e358c5>", line 25, in <module>
#     callbacks=[checkpoint, reduce_lr, tblr])
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py", line 2065, in fit_generator
#     initial_epoch=initial_epoch)
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/site-packages/tensorflow/python/keras/engine/training_generator.py", line 219, in fit_generator
#     enqueuer.stop()
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/site-packages/tensorflow/python/keras/utils/data_utils.py", line 633, in stop
#     self.run_thread.join(timeout)
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/threading.py", line 1056, in join
#     self._wait_for_tstate_lock()
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/threading.py", line 1072, in _wait_for_tstate_lock
#     elif lock.acquire(block, timeout):
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2018, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3191, in run_ast_nodes
#     if (yield from self.run_code(code, result)):
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3284, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2021, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1373, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1281, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1144, in structured_traceback
#     formatted_exceptions += self.prepare_chained_exception_message(evalue.__cause__)
# TypeError: must be str, not list
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2018, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1095, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 313, in wrapped
#     return f(*args, **kwargs)
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 347, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/inspect.py", line 1488, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/inspect.py", line 1446, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/inspect.py", line 739, in getmodule
#     f = getabsfile(module)
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/inspect.py", line 708, in getabsfile
#     _filename = getsourcefile(object) or getfile(object)
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/inspect.py", line 693, in getsourcefile
#     if os.path.exists(filename):
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/genericpath.py", line 19, in exists
#     os.stat(path)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/site-packages/tensorflow/python/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     170         outs = model.train_on_batch(
# --> 171             x, y, sample_weight=sample_weight, class_weight=class_weight)
#     172
#
# ~/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1827       self._make_train_function()
# -> 1828       outputs = self.train_function(ins)
#    1829
#
# ~/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/site-packages/tensorflow/python/keras/backend.py in __call__(self, inputs)
#    2977     fetched = self._callable_fn(*array_vals,
# -> 2978                                 run_metadata=self.run_metadata)
#    2979     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#
# ~/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1398               self._session._session, self._handle, args, status,
# -> 1399               run_metadata_ptr)
#    1400         if run_metadata:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2017                         # in the engines. This should return a list of strings.
# -> 2018                         stb = value._render_traceback_()
#    2019                     except Exception:
#
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py in run_code(self, code_obj, result, async_)
#    3282             if result is not None:
#    3283                 result.error_in_exec = sys.exc_info()[1]
# -> 3284             self.showtraceback(running_compiled_code=True)
#    3285         else:
#    3286             outflag = False
#
# ~/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2019                     except Exception:
#    2020                         stb = self.InteractiveTB.structured_traceback(etype,
# -> 2021                                             value, tb, tb_offset=tb_offset)
#    2022
#    2023                     self._showtraceback(etype, value, stb)
#
# ~/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1371         self.tb = tb
#    1372         return FormattedTB.structured_traceback(
# -> 1373             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1374
#    1375
#
# ~/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1279             # Verbose modes need a full traceback
#    1280             return VerboseTB.structured_traceback(
# -> 1281                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1282             )
#    1283         else:
#
# ~/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1142         exception = self.get_parts_of_chained_exception(evalue)
#    1143         if exception:
# -> 1144             formatted_exceptions += self.prepare_chained_exception_message(evalue.__cause__)
#    1145             etype, evalue, etb = exception
#    1146         else:
#
# TypeError: must be str, not list
