# %%
import os
import tensorflow as tf
import dask
import dask.array as da
import numpy as np

# %%
train_x = da.from_npy_stack('/home/skyolia/JupyterProjects/classification/cifar_10/data/train_x')
train_y = da.from_npy_stack('/home/skyolia/JupyterProjects/classification/cifar_10/data/train_y')
test_x = da.from_npy_stack('/home/skyolia/JupyterProjects/classification/cifar_10/data/test_x')
test_y = da.from_npy_stack('/home/skyolia/JupyterProjects/classification/cifar_10/data/test_y')
train_x, train_y, test_x, test_y
# Out:
# (dask.array<from-npy-stack, shape=(50000, 32, 32, 3), dtype=float64, chunksize=(10000, 32, 32, 3)>,
#  dask.array<from-npy-stack, shape=(50000, 1), dtype=float64, chunksize=(10000, 1)>,
#  dask.array<from-npy-stack, shape=(10000, 32, 32, 3), dtype=float64, chunksize=(1000, 32, 32, 3)>,
#  dask.array<from-npy-stack, shape=(10000, 1), dtype=float64, chunksize=(1000, 1)>)

# %%
class CIFAR10Sequence(tf.keras.utils.Sequence):

    def __init__(self, x, y, batch_size):
        self.x, self.y = x, y
        self.batch_size = batch_size

    def __len__(self):
        return int(np.ceil(len(self.x) / float(self.batch_size)))

    def __getitem__(self, idx):
        batch_x = self.x[idx * self.batch_size:(idx + 1) * self.batch_size]
        batch_y = self.y[idx * self.batch_size:(idx + 1) * self.batch_size]
        return batch_x, batch_y
        
class LRTensorBoard(tf.keras.callbacks.TensorBoard):
    '''
    Add learning rate evolution to Tensorboard
    '''
    def __init__(self, log_dir):
        super().__init__(log_dir=log_dir)

    def on_epoch_end(self, epoch, logs=None):
        logs['lr'] = tf.keras.backend.eval(self.model.optimizer.lr)
        super().on_epoch_end(epoch, logs)

def build_block(input_layer, filters, norm=True, k=[3,3]):
    layer = tf.keras.layers.Conv2D(filters, kernel_size=(k[0], k[1]), padding='same', use_bias=not norm, kernel_initializer='glorot_uniform')(input_layer)
    if norm:
        layer = tf.keras.layers.BatchNormalization()(layer)
    layer = tf.keras.layers.Activation('elu')(layer)
    return layer

def build_model(num_class):
    image_input = tf.keras.Input(shape=(32, 32, 3), name='input_layer')
    conv_1 = build_block(image_input, 48)
    conv_2 = build_block(conv_1, 48)
    pool_1 = tf.keras.layers.MaxPooling2D(padding='same')(conv_2)
    drop_1 = tf.keras.layers.Dropout(0.6)(pool_1)
    conv_3 = build_block(drop_1, 96)
    conv_4 = build_block(conv_3, 96)
    pool_2 = tf.keras.layers.MaxPooling2D(padding='same')(conv_4)
    drop_2 = tf.keras.layers.Dropout(0.6)(pool_2)
    conv_5 = build_block(drop_2, 192)
    conv_6 = build_block(conv_5, 192)
    pool_3 = tf.keras.layers.MaxPooling2D(padding='same')(conv_6)
    drop_3 = tf.keras.layers.Dropout(0.6)(pool_3)
    conv_7 = build_block(drop_3, 192, False, [1,1])
    drop_4 = tf.keras.layers.Dropout(0.25)(conv_7)
    gap = tf.keras.layers.GlobalAvgPool2D()(drop_4)
    logits = tf.keras.layers.Dense(units=num_class, activation='softmax', bias_initializer='ones', kernel_initializer='glorot_uniform')(gap)
    model = tf.keras.Model(inputs=image_input, outputs=logits)
    return model

# %%
model = build_model(10)
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer (InputLayer)     (None, 32, 32, 3)         0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 32, 32, 48)        1296
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32, 32, 48)        192
# _________________________________________________________________
# activation (Activation)      (None, 32, 32, 48)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 48)        20736
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 48)        192
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 48)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 48)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 16, 48)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 96)        41472
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16, 16, 96)        384
# _________________________________________________________________
# activation_2 (Activation)    (None, 16, 16, 96)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 96)        82944
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 16, 16, 96)        384
# _________________________________________________________________
# activation_3 (Activation)    (None, 16, 16, 96)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 96)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8, 8, 96)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 192)         165888
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 8, 8, 192)         768
# _________________________________________________________________
# activation_4 (Activation)    (None, 8, 8, 192)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 192)         331776
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 8, 8, 192)         768
# _________________________________________________________________
# activation_5 (Activation)    (None, 8, 8, 192)         0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 192)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 4, 192)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 4, 4, 192)         37056
# _________________________________________________________________
# activation_6 (Activation)    (None, 4, 4, 192)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 4, 4, 192)         0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 192)               0
# _________________________________________________________________
# dense (Dense)                (None, 10)                1930
# =================================================================
# Total params: 685,786
# Trainable params: 684,442
# Non-trainable params: 1,344
# _________________________________________________________________

# %%
model.load_weights("day_1.weights.best.hdf5")
sgd = tf.keras.optimizers.SGD(lr=1.5)
model.compile(loss='sparse_categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
scores = model.evaluate(test_x, test_y)
scores
# Out:
# 10000/10000 [==============================] - 4s 446us/step
# [0.4764824456214905, 0.8424]

# %%
epochs, lr, batch_size = 10000, 1., 256
steps_per_epoch = int(np.ceil(train_y.shape[0]/batch_size))
filepath="day_1.weights.best.hdf5"

train_generator = CIFAR10Sequence(train_x, train_y, batch_size)
test_generator = CIFAR10Sequence(test_x, test_y, batch_size)
tblr = LRTensorBoard(log_dir=os.getcwd())
checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=15, min_lr=0.008, mode='min', cooldown=1, verbose=1)

sgd = tf.keras.optimizers.SGD(lr=lr) # 
model.compile(loss='sparse_categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

#model.load_weights(filepath)
model.fit_generator(generator=train_generator,
                    steps_per_epoch=steps_per_epoch,
                    epochs=epochs,
                    verbose=1,
                    validation_data=test_generator,
                    validation_steps=int(np.ceil(test_y.shape[0]/batch_size)),
                    use_multiprocessing=True,
                    workers=12,
                    shuffle=True,
                    #initial_epoch=65,
                    callbacks=[checkpoint, reduce_lr, tblr])
# Out:
# Epoch 1/10000
# 195/196 [============================>.] - ETA: 0s - loss: 7.5661 - acc: 0.1585
# Epoch 00001: val_acc improved from -inf to 0.24880, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 37s 190ms/step - loss: 7.5382 - acc: 0.1591 - val_loss: 2.0150 - val_acc: 0.2488
# Epoch 2/10000
# 195/196 [============================>.] - ETA: 0s - loss: 1.9065 - acc: 0.2777
# Epoch 00002: val_acc improved from 0.24880 to 0.28880, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 33s 167ms/step - loss: 1.9057 - acc: 0.2780 - val_loss: 1.8430 - val_acc: 0.2888
# Epoch 3/10000
# 195/196 [============================>.] - ETA: 0s - loss: 1.7301 - acc: 0.3492
# Epoch 00003: val_acc improved from 0.28880 to 0.36810, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 33s 169ms/step - loss: 1.7297 - acc: 0.3495 - val_loss: 1.6792 - val_acc: 0.3681
# Epoch 4/10000
# 195/196 [============================>.] - ETA: 0s - loss: 1.5740 - acc: 0.4131
# Epoch 00004: val_acc improved from 0.36810 to 0.45020, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 33s 170ms/step - loss: 1.5740 - acc: 0.4131 - val_loss: 1.4781 - val_acc: 0.4502
# Epoch 5/10000
# 195/196 [============================>.] - ETA: 0s - loss: 1.4685 - acc: 0.4555
# Epoch 00005: val_acc improved from 0.45020 to 0.46720, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 33s 170ms/step - loss: 1.4680 - acc: 0.4559 - val_loss: 1.4570 - val_acc: 0.4672
# Epoch 6/10000
# 195/196 [============================>.] - ETA: 0s - loss: 1.3632 - acc: 0.4967
# Epoch 00006: val_acc improved from 0.46720 to 0.54160, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 33s 170ms/step - loss: 1.3625 - acc: 0.4969 - val_loss: 1.2489 - val_acc: 0.5416
# Epoch 7/10000
# 195/196 [============================>.] - ETA: 0s - loss: 1.2676 - acc: 0.5393
# Epoch 00007: val_acc did not improve from 0.54160
# 196/196 [==============================] - 33s 170ms/step - loss: 1.2679 - acc: 0.5390 - val_loss: 1.4104 - val_acc: 0.4923
# Epoch 8/10000
# 195/196 [============================>.] - ETA: 0s - loss: 1.1867 - acc: 0.5677
# Epoch 00008: val_acc did not improve from 0.54160
# 196/196 [==============================] - 33s 171ms/step - loss: 1.1873 - acc: 0.5673 - val_loss: 1.5718 - val_acc: 0.4748
# Epoch 9/10000
# 195/196 [============================>.] - ETA: 0s - loss: 1.1295 - acc: 0.5902
# Epoch 00009: val_acc improved from 0.54160 to 0.63230, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 33s 171ms/step - loss: 1.1296 - acc: 0.5903 - val_loss: 1.0060 - val_acc: 0.6323
# Epoch 10/10000
# 195/196 [============================>.] - ETA: 0s - loss: 1.0802 - acc: 0.6104
# Epoch 00010: val_acc did not improve from 0.63230
# 196/196 [==============================] - 33s 171ms/step - loss: 1.0794 - acc: 0.6107 - val_loss: 1.0187 - val_acc: 0.6281
# Epoch 11/10000
# 195/196 [============================>.] - ETA: 0s - loss: 1.0393 - acc: 0.6254
# Epoch 00011: val_acc improved from 0.63230 to 0.64290, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 34s 171ms/step - loss: 1.0389 - acc: 0.6255 - val_loss: 0.9839 - val_acc: 0.6429
# Epoch 12/10000
# 195/196 [============================>.] - ETA: 0s - loss: 1.0041 - acc: 0.6374
# Epoch 00012: val_acc did not improve from 0.64290
# 196/196 [==============================] - 33s 171ms/step - loss: 1.0047 - acc: 0.6373 - val_loss: 0.9927 - val_acc: 0.6391
# Epoch 13/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.9760 - acc: 0.6497
# Epoch 00013: val_acc improved from 0.64290 to 0.64380, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 34s 171ms/step - loss: 0.9759 - acc: 0.6498 - val_loss: 1.0181 - val_acc: 0.6438
# Epoch 14/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.9465 - acc: 0.6566
# Epoch 00014: val_acc improved from 0.64380 to 0.67420, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 33s 171ms/step - loss: 0.9462 - acc: 0.6569 - val_loss: 0.9324 - val_acc: 0.6742
# Epoch 15/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.9211 - acc: 0.6689
# Epoch 00015: val_acc improved from 0.67420 to 0.69060, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 34s 172ms/step - loss: 0.9208 - acc: 0.6691 - val_loss: 0.8495 - val_acc: 0.6906
# Epoch 16/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.8975 - acc: 0.6781
# Epoch 00016: val_acc did not improve from 0.69060
# 196/196 [==============================] - 34s 171ms/step - loss: 0.8975 - acc: 0.6779 - val_loss: 1.1812 - val_acc: 0.5996
# Epoch 17/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.8716 - acc: 0.6855
# Epoch 00017: val_acc improved from 0.69060 to 0.70610, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 34s 171ms/step - loss: 0.8718 - acc: 0.6856 - val_loss: 0.8180 - val_acc: 0.7061
# Epoch 18/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.8526 - acc: 0.6963
# Epoch 00018: val_acc improved from 0.70610 to 0.71460, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 34s 171ms/step - loss: 0.8530 - acc: 0.6964 - val_loss: 0.8023 - val_acc: 0.7146
# Epoch 19/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.8297 - acc: 0.7036
# Epoch 00019: val_acc improved from 0.71460 to 0.73540, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 34s 171ms/step - loss: 0.8299 - acc: 0.7034 - val_loss: 0.7558 - val_acc: 0.7354
# Epoch 20/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.8073 - acc: 0.7124
# Epoch 00020: val_acc did not improve from 0.73540
# 196/196 [==============================] - 34s 171ms/step - loss: 0.8074 - acc: 0.7123 - val_loss: 0.8113 - val_acc: 0.7127
# Epoch 21/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.7874 - acc: 0.7205
# Epoch 00021: val_acc improved from 0.73540 to 0.74510, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 34s 172ms/step - loss: 0.7875 - acc: 0.7205 - val_loss: 0.7236 - val_acc: 0.7451
# Epoch 22/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.7677 - acc: 0.7266
# Epoch 00022: val_acc improved from 0.74510 to 0.75550, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 34s 171ms/step - loss: 0.7677 - acc: 0.7266 - val_loss: 0.7040 - val_acc: 0.7555
# Epoch 23/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.7568 - acc: 0.7311
# Epoch 00023: val_acc improved from 0.75550 to 0.77320, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 34s 172ms/step - loss: 0.7569 - acc: 0.7311 - val_loss: 0.6690 - val_acc: 0.7732
# Epoch 24/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.7392 - acc: 0.7383
# Epoch 00024: val_acc did not improve from 0.77320
# 196/196 [==============================] - 34s 171ms/step - loss: 0.7388 - acc: 0.7382 - val_loss: 0.7415 - val_acc: 0.7422
# Epoch 25/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.7202 - acc: 0.7460
# Epoch 00025: val_acc did not improve from 0.77320
# 196/196 [==============================] - 34s 172ms/step - loss: 0.7207 - acc: 0.7457 - val_loss: 0.6877 - val_acc: 0.7641
# Epoch 26/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.7127 - acc: 0.7473
# Epoch 00026: val_acc did not improve from 0.77320
# 196/196 [==============================] - 34s 172ms/step - loss: 0.7129 - acc: 0.7472 - val_loss: 0.6739 - val_acc: 0.7702
# Epoch 27/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.6927 - acc: 0.7557
# Epoch 00027: val_acc improved from 0.77320 to 0.78090, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 34s 172ms/step - loss: 0.6925 - acc: 0.7558 - val_loss: 0.6402 - val_acc: 0.7809
# Epoch 28/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.6807 - acc: 0.7607
# Epoch 00028: val_acc did not improve from 0.78090
# 196/196 [==============================] - 34s 172ms/step - loss: 0.6812 - acc: 0.7605 - val_loss: 0.7123 - val_acc: 0.7587
# Epoch 29/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.6706 - acc: 0.7636
# Epoch 00029: val_acc improved from 0.78090 to 0.78990, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 34s 171ms/step - loss: 0.6706 - acc: 0.7634 - val_loss: 0.6081 - val_acc: 0.7899
# Epoch 30/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.6554 - acc: 0.7696
# Epoch 00030: val_acc did not improve from 0.78990
# 196/196 [==============================] - 33s 171ms/step - loss: 0.6552 - acc: 0.7696 - val_loss: 0.6317 - val_acc: 0.7854
# Epoch 31/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.6496 - acc: 0.7718
# Epoch 00031: val_acc did not improve from 0.78990
# 196/196 [==============================] - 33s 171ms/step - loss: 0.6493 - acc: 0.7719 - val_loss: 0.6275 - val_acc: 0.7804
# Epoch 32/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.6364 - acc: 0.7756
# Epoch 00032: val_acc did not improve from 0.78990
# 196/196 [==============================] - 34s 171ms/step - loss: 0.6362 - acc: 0.7757 - val_loss: 0.6265 - val_acc: 0.7873
# Epoch 33/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.6273 - acc: 0.7783
# Epoch 00033: val_acc did not improve from 0.78990
# 196/196 [==============================] - 33s 171ms/step - loss: 0.6275 - acc: 0.7781 - val_loss: 0.6302 - val_acc: 0.7855
# Epoch 34/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.6229 - acc: 0.7816
# Epoch 00034: val_acc did not improve from 0.78990
# 196/196 [==============================] - 34s 171ms/step - loss: 0.6222 - acc: 0.7817 - val_loss: 0.6522 - val_acc: 0.7779
# Epoch 35/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.6077 - acc: 0.7855
# Epoch 00035: val_acc improved from 0.78990 to 0.80590, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 34s 171ms/step - loss: 0.6075 - acc: 0.7854 - val_loss: 0.5684 - val_acc: 0.8059
# Epoch 36/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.5989 - acc: 0.7903
# Epoch 00036: val_acc did not improve from 0.80590
# 196/196 [==============================] - 34s 171ms/step - loss: 0.5989 - acc: 0.7902 - val_loss: 0.6272 - val_acc: 0.7872
# Epoch 37/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.5907 - acc: 0.7930
# Epoch 00037: val_acc did not improve from 0.80590
# 196/196 [==============================] - 33s 171ms/step - loss: 0.5907 - acc: 0.7930 - val_loss: 0.6441 - val_acc: 0.7843
# Epoch 38/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.5816 - acc: 0.7953
# Epoch 00038: val_acc improved from 0.80590 to 0.80820, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 34s 171ms/step - loss: 0.5815 - acc: 0.7953 - val_loss: 0.5714 - val_acc: 0.8082
# Epoch 39/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.5748 - acc: 0.7988
# Epoch 00039: val_acc improved from 0.80820 to 0.81290, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 34s 171ms/step - loss: 0.5742 - acc: 0.7990 - val_loss: 0.5477 - val_acc: 0.8129
# Epoch 40/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.5691 - acc: 0.7999
# Epoch 00040: val_acc did not improve from 0.81290
# 196/196 [==============================] - 34s 171ms/step - loss: 0.5692 - acc: 0.7999 - val_loss: 0.6431 - val_acc: 0.7831
# Epoch 41/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.5611 - acc: 0.8036
# Epoch 00041: val_acc did not improve from 0.81290
# 196/196 [==============================] - 33s 171ms/step - loss: 0.5614 - acc: 0.8035 - val_loss: 0.6482 - val_acc: 0.7842
# Epoch 42/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.5601 - acc: 0.8030
# Epoch 00042: val_acc did not improve from 0.81290
# 196/196 [==============================] - 34s 171ms/step - loss: 0.5597 - acc: 0.8030 - val_loss: 0.5956 - val_acc: 0.8005
# Epoch 43/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.5443 - acc: 0.8077
# Epoch 00043: val_acc did not improve from 0.81290
# 196/196 [==============================] - 34s 171ms/step - loss: 0.5439 - acc: 0.8079 - val_loss: 0.6046 - val_acc: 0.7999
# Epoch 44/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.5458 - acc: 0.8094
# Epoch 00044: val_acc did not improve from 0.81290
# 196/196 [==============================] - 34s 171ms/step - loss: 0.5460 - acc: 0.8094 - val_loss: 0.5605 - val_acc: 0.8114
# Epoch 45/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.5368 - acc: 0.8113
# Epoch 00045: val_acc did not improve from 0.81290
# 196/196 [==============================] - 34s 171ms/step - loss: 0.5368 - acc: 0.8114 - val_loss: 0.5702 - val_acc: 0.8098
# Epoch 46/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.5292 - acc: 0.8146
# Epoch 00046: val_acc did not improve from 0.81290
# 196/196 [==============================] - 33s 171ms/step - loss: 0.5294 - acc: 0.8146 - val_loss: 0.6004 - val_acc: 0.8028
# Epoch 47/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.5227 - acc: 0.8166
# Epoch 00047: val_acc improved from 0.81290 to 0.82490, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 34s 171ms/step - loss: 0.5229 - acc: 0.8167 - val_loss: 0.5175 - val_acc: 0.8249
# Epoch 48/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.5161 - acc: 0.8172
# Epoch 00048: val_acc improved from 0.82490 to 0.83060, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 34s 171ms/step - loss: 0.5162 - acc: 0.8171 - val_loss: 0.5096 - val_acc: 0.8306
# Epoch 49/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.5123 - acc: 0.8186
# Epoch 00049: val_acc improved from 0.83060 to 0.83470, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 34s 171ms/step - loss: 0.5124 - acc: 0.8185 - val_loss: 0.4819 - val_acc: 0.8347
# Epoch 50/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.5080 - acc: 0.8208
# Epoch 00050: val_acc improved from 0.83470 to 0.83530, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 34s 171ms/step - loss: 0.5078 - acc: 0.8209 - val_loss: 0.5002 - val_acc: 0.8353
# Epoch 51/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.5022 - acc: 0.8232
# Epoch 00051: val_acc did not improve from 0.83530
# 196/196 [==============================] - 34s 171ms/step - loss: 0.5020 - acc: 0.8232 - val_loss: 0.5505 - val_acc: 0.8145
# Epoch 52/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.4957 - acc: 0.8264
# Epoch 00052: val_acc did not improve from 0.83530
# 196/196 [==============================] - 33s 171ms/step - loss: 0.4956 - acc: 0.8264 - val_loss: 0.5295 - val_acc: 0.8268
# Epoch 53/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.4895 - acc: 0.8293
# Epoch 00053: val_acc improved from 0.83530 to 0.84110, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 33s 171ms/step - loss: 0.4890 - acc: 0.8295 - val_loss: 0.4939 - val_acc: 0.8411
# Epoch 54/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.4881 - acc: 0.8294
# Epoch 00054: val_acc did not improve from 0.84110
# 196/196 [==============================] - 34s 171ms/step - loss: 0.4880 - acc: 0.8293 - val_loss: 0.5038 - val_acc: 0.8310
# Epoch 55/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.4869 - acc: 0.8286
# Epoch 00055: val_acc improved from 0.84110 to 0.84130, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 34s 171ms/step - loss: 0.4867 - acc: 0.8286 - val_loss: 0.4835 - val_acc: 0.8413
# Epoch 56/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.4783 - acc: 0.8320
# Epoch 00056: val_acc did not improve from 0.84130
# 196/196 [==============================] - 34s 171ms/step - loss: 0.4786 - acc: 0.8318 - val_loss: 0.5810 - val_acc: 0.8125
# Epoch 57/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.4731 - acc: 0.8338
# Epoch 00057: val_acc did not improve from 0.84130
# 196/196 [==============================] - 34s 171ms/step - loss: 0.4734 - acc: 0.8336 - val_loss: 0.5177 - val_acc: 0.8231
# Epoch 58/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.4649 - acc: 0.8353
# Epoch 00058: val_acc did not improve from 0.84130
# 196/196 [==============================] - 33s 171ms/step - loss: 0.4654 - acc: 0.8351 - val_loss: 0.4697 - val_acc: 0.8409
# Epoch 59/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.4610 - acc: 0.8385
# Epoch 00059: val_acc did not improve from 0.84130
# 196/196 [==============================] - 34s 171ms/step - loss: 0.4612 - acc: 0.8385 - val_loss: 0.5377 - val_acc: 0.8160
# Epoch 60/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.4568 - acc: 0.8394
# Epoch 00060: val_acc did not improve from 0.84130
# 196/196 [==============================] - 33s 171ms/step - loss: 0.4568 - acc: 0.8393 - val_loss: 0.4993 - val_acc: 0.8381
# Epoch 61/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.4580 - acc: 0.8382
# Epoch 00061: val_acc improved from 0.84130 to 0.84380, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 34s 171ms/step - loss: 0.4579 - acc: 0.8383 - val_loss: 0.4608 - val_acc: 0.8438
# Epoch 62/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.4514 - acc: 0.8407
# Epoch 00062: val_acc improved from 0.84380 to 0.84440, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 34s 172ms/step - loss: 0.4518 - acc: 0.8406 - val_loss: 0.4819 - val_acc: 0.8444
# Epoch 63/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.4504 - acc: 0.8412
# Epoch 00063: val_acc improved from 0.84440 to 0.84590, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 34s 171ms/step - loss: 0.4503 - acc: 0.8413 - val_loss: 0.4728 - val_acc: 0.8459
# Epoch 64/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.4389 - acc: 0.8457
# Epoch 00064: val_acc did not improve from 0.84590
# 196/196 [==============================] - 34s 171ms/step - loss: 0.4387 - acc: 0.8459 - val_loss: 0.4973 - val_acc: 0.8400
# Epoch 65/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.4434 - acc: 0.8415
# Epoch 00065: val_acc improved from 0.84590 to 0.85140, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 34s 171ms/step - loss: 0.4434 - acc: 0.8416 - val_loss: 0.4525 - val_acc: 0.8514
# Epoch 66/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.4380 - acc: 0.8465
# Epoch 00066: val_acc did not improve from 0.85140
# 196/196 [==============================] - 34s 171ms/step - loss: 0.4381 - acc: 0.8464 - val_loss: 0.4987 - val_acc: 0.8400
# Epoch 67/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.4338 - acc: 0.8462
# Epoch 00067: val_acc improved from 0.85140 to 0.85590, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 34s 171ms/step - loss: 0.4339 - acc: 0.8462 - val_loss: 0.4368 - val_acc: 0.8559
# Epoch 68/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.4302 - acc: 0.8493
# Epoch 00068: val_acc did not improve from 0.85590
# 196/196 [==============================] - 34s 171ms/step - loss: 0.4300 - acc: 0.8494 - val_loss: 0.4552 - val_acc: 0.8516
# Epoch 69/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.4226 - acc: 0.8500
# Epoch 00069: val_acc did not improve from 0.85590
# 196/196 [==============================] - 33s 171ms/step - loss: 0.4222 - acc: 0.8502 - val_loss: 0.4680 - val_acc: 0.8521
# Epoch 70/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.4224 - acc: 0.8502
# Epoch 00070: val_acc did not improve from 0.85590
# 196/196 [==============================] - 33s 171ms/step - loss: 0.4225 - acc: 0.8501 - val_loss: 0.5065 - val_acc: 0.8387
# Epoch 71/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.4196 - acc: 0.8514
# Epoch 00071: val_acc did not improve from 0.85590
# 196/196 [==============================] - 34s 171ms/step - loss: 0.4196 - acc: 0.8514 - val_loss: 0.4949 - val_acc: 0.8368
# Epoch 72/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.4203 - acc: 0.8527
# Epoch 00072: val_acc did not improve from 0.85590
# 196/196 [==============================] - 34s 171ms/step - loss: 0.4201 - acc: 0.8529 - val_loss: 0.4585 - val_acc: 0.8521
# Epoch 73/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.4186 - acc: 0.8536
# Epoch 00073: val_acc did not improve from 0.85590
# 196/196 [==============================] - 33s 171ms/step - loss: 0.4188 - acc: 0.8535 - val_loss: 0.4780 - val_acc: 0.8415
# Epoch 74/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.4109 - acc: 0.8540
# Epoch 00074: val_acc did not improve from 0.85590
# 196/196 [==============================] - 33s 171ms/step - loss: 0.4111 - acc: 0.8538 - val_loss: 0.4815 - val_acc: 0.8470
# Epoch 75/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.4046 - acc: 0.8569
# Epoch 00075: val_acc did not improve from 0.85590
# 196/196 [==============================] - 34s 171ms/step - loss: 0.4045 - acc: 0.8570 - val_loss: 0.4595 - val_acc: 0.8535
# Epoch 76/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.4076 - acc: 0.8566
# Epoch 00076: val_acc did not improve from 0.85590
# 196/196 [==============================] - 34s 171ms/step - loss: 0.4075 - acc: 0.8566 - val_loss: 0.5571 - val_acc: 0.8266
# Epoch 77/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.4035 - acc: 0.8577
# Epoch 00077: val_acc did not improve from 0.85590
# 196/196 [==============================] - 33s 171ms/step - loss: 0.4038 - acc: 0.8577 - val_loss: 0.4965 - val_acc: 0.8446
# Epoch 78/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.4014 - acc: 0.8585
# Epoch 00078: val_acc did not improve from 0.85590
# 196/196 [==============================] - 34s 171ms/step - loss: 0.4012 - acc: 0.8586 - val_loss: 0.5287 - val_acc: 0.8299
# Epoch 79/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.3989 - acc: 0.8571
# Epoch 00079: val_acc did not improve from 0.85590
# 196/196 [==============================] - 33s 171ms/step - loss: 0.3991 - acc: 0.8570 - val_loss: 0.5089 - val_acc: 0.8353
# Epoch 80/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.3968 - acc: 0.8598
# Epoch 00080: val_acc did not improve from 0.85590
# 196/196 [==============================] - 33s 171ms/step - loss: 0.3970 - acc: 0.8597 - val_loss: 0.5030 - val_acc: 0.8422
# Epoch 81/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.3926 - acc: 0.8608
# Epoch 00081: val_acc did not improve from 0.85590
# 196/196 [==============================] - 34s 171ms/step - loss: 0.3923 - acc: 0.8609 - val_loss: 0.4805 - val_acc: 0.8494
# Epoch 82/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.3887 - acc: 0.8625
# Epoch 00082: val_acc improved from 0.85590 to 0.86170, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 34s 171ms/step - loss: 0.3886 - acc: 0.8625 - val_loss: 0.4328 - val_acc: 0.8617
# Epoch 83/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.3856 - acc: 0.8634
# Epoch 00083: val_acc did not improve from 0.86170
# 196/196 [==============================] - 34s 172ms/step - loss: 0.3856 - acc: 0.8634 - val_loss: 0.4897 - val_acc: 0.8443
# Epoch 84/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.3829 - acc: 0.8640
# Epoch 00084: val_acc did not improve from 0.86170
# 196/196 [==============================] - 34s 171ms/step - loss: 0.3829 - acc: 0.8639 - val_loss: 0.4726 - val_acc: 0.8548
# Epoch 85/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.3822 - acc: 0.8649
# Epoch 00085: val_acc did not improve from 0.86170
# 196/196 [==============================] - 34s 171ms/step - loss: 0.3820 - acc: 0.8650 - val_loss: 0.5189 - val_acc: 0.8392
# Epoch 86/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.3789 - acc: 0.8647
# Epoch 00086: val_acc did not improve from 0.86170
# 196/196 [==============================] - 34s 171ms/step - loss: 0.3788 - acc: 0.8648 - val_loss: 0.4385 - val_acc: 0.8612
# Epoch 87/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.3788 - acc: 0.8653
# Epoch 00087: val_acc did not improve from 0.86170
# 196/196 [==============================] - 34s 171ms/step - loss: 0.3784 - acc: 0.8655 - val_loss: 0.4816 - val_acc: 0.8492
# Epoch 88/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.3763 - acc: 0.8665
# Epoch 00088: val_acc improved from 0.86170 to 0.86760, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 34s 171ms/step - loss: 0.3761 - acc: 0.8666 - val_loss: 0.4070 - val_acc: 0.8676
# Epoch 89/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.3734 - acc: 0.8672
# Epoch 00089: val_acc did not improve from 0.86760
# 196/196 [==============================] - 33s 171ms/step - loss: 0.3731 - acc: 0.8674 - val_loss: 0.5075 - val_acc: 0.8361
# Epoch 90/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.3675 - acc: 0.8697
# Epoch 00090: val_acc did not improve from 0.86760
# 196/196 [==============================] - 33s 171ms/step - loss: 0.3675 - acc: 0.8698 - val_loss: 0.4497 - val_acc: 0.8630
# Epoch 91/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.3580 - acc: 0.8722
# Epoch 00091: val_acc improved from 0.86760 to 0.86990, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 34s 171ms/step - loss: 0.3581 - acc: 0.8722 - val_loss: 0.4192 - val_acc: 0.8699
# Epoch 92/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.3574 - acc: 0.8737
# Epoch 00092: val_acc did not improve from 0.86990
# 196/196 [==============================] - 34s 171ms/step - loss: 0.3577 - acc: 0.8736 - val_loss: 0.4416 - val_acc: 0.8622
# Epoch 93/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.3600 - acc: 0.8718
# Epoch 00093: val_acc did not improve from 0.86990
# 196/196 [==============================] - 34s 171ms/step - loss: 0.3595 - acc: 0.8720 - val_loss: 0.4364 - val_acc: 0.8600
# Epoch 94/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.3586 - acc: 0.8731
# Epoch 00094: val_acc did not improve from 0.86990
# 196/196 [==============================] - 33s 171ms/step - loss: 0.3583 - acc: 0.8732 - val_loss: 0.4781 - val_acc: 0.8494
# Epoch 95/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.3508 - acc: 0.8748
# Epoch 00095: val_acc did not improve from 0.86990
# 196/196 [==============================] - 33s 171ms/step - loss: 0.3508 - acc: 0.8747 - val_loss: 0.5038 - val_acc: 0.8527
# Epoch 96/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.3503 - acc: 0.8761
# Epoch 00096: val_acc did not improve from 0.86990
# 196/196 [==============================] - 34s 171ms/step - loss: 0.3502 - acc: 0.8762 - val_loss: 0.4344 - val_acc: 0.8636
# Epoch 97/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.3535 - acc: 0.8754
# Epoch 00097: val_acc did not improve from 0.86990
# 196/196 [==============================] - 34s 171ms/step - loss: 0.3532 - acc: 0.8755 - val_loss: 0.4338 - val_acc: 0.8650
# Epoch 98/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.3450 - acc: 0.8775
# Epoch 00098: val_acc did not improve from 0.86990
# 196/196 [==============================] - 33s 171ms/step - loss: 0.3449 - acc: 0.8777 - val_loss: 0.4382 - val_acc: 0.8651
# Epoch 99/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.3490 - acc: 0.8752
# Epoch 00099: val_acc did not improve from 0.86990
# 196/196 [==============================] - 34s 171ms/step - loss: 0.3492 - acc: 0.8752 - val_loss: 0.4988 - val_acc: 0.8495
# Epoch 100/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.3463 - acc: 0.8768
# Epoch 00100: val_acc did not improve from 0.86990
# 196/196 [==============================] - 34s 171ms/step - loss: 0.3461 - acc: 0.8769 - val_loss: 0.4512 - val_acc: 0.8588
# Epoch 101/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.3425 - acc: 0.8790
# Epoch 00101: val_acc did not improve from 0.86990
# 196/196 [==============================] - 33s 171ms/step - loss: 0.3425 - acc: 0.8790 - val_loss: 0.4231 - val_acc: 0.8680
# Epoch 102/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.3419 - acc: 0.8794
# Epoch 00102: val_acc did not improve from 0.86990
# 196/196 [==============================] - 33s 171ms/step - loss: 0.3416 - acc: 0.8794 - val_loss: 0.4387 - val_acc: 0.8634
# Epoch 103/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.3359 - acc: 0.8824
# Epoch 00103: val_acc improved from 0.86990 to 0.87130, saving model to day_1.weights.best.hdf5
#
# Epoch 00103: ReduceLROnPlateau reducing learning rate to 0.5.
# 196/196 [==============================] - 34s 172ms/step - loss: 0.3360 - acc: 0.8823 - val_loss: 0.4074 - val_acc: 0.8713
# Epoch 104/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.3045 - acc: 0.8923
# Epoch 00104: val_acc improved from 0.87130 to 0.87830, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 34s 171ms/step - loss: 0.3044 - acc: 0.8923 - val_loss: 0.3881 - val_acc: 0.8783
# Epoch 105/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2974 - acc: 0.8941
# Epoch 00105: val_acc improved from 0.87830 to 0.88260, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 34s 171ms/step - loss: 0.2973 - acc: 0.8942 - val_loss: 0.3781 - val_acc: 0.8826
# Epoch 106/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2881 - acc: 0.8960
# Epoch 00106: val_acc did not improve from 0.88260
# 196/196 [==============================] - 34s 171ms/step - loss: 0.2881 - acc: 0.8961 - val_loss: 0.4530 - val_acc: 0.8658
# Epoch 107/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2914 - acc: 0.8968
# Epoch 00107: val_acc did not improve from 0.88260
# 196/196 [==============================] - 34s 171ms/step - loss: 0.2913 - acc: 0.8968 - val_loss: 0.4194 - val_acc: 0.8723
# Epoch 108/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2919 - acc: 0.8963
# Epoch 00108: val_acc did not improve from 0.88260
# 196/196 [==============================] - 34s 171ms/step - loss: 0.2919 - acc: 0.8964 - val_loss: 0.4048 - val_acc: 0.8761
# Epoch 109/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2851 - acc: 0.8990
# Epoch 00109: val_acc did not improve from 0.88260
# 196/196 [==============================] - 34s 171ms/step - loss: 0.2853 - acc: 0.8990 - val_loss: 0.4535 - val_acc: 0.8683
# Epoch 110/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2841 - acc: 0.8997
# Epoch 00110: val_acc did not improve from 0.88260
# 196/196 [==============================] - 34s 171ms/step - loss: 0.2842 - acc: 0.8996 - val_loss: 0.3969 - val_acc: 0.8805
# Epoch 111/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2805 - acc: 0.8997
# Epoch 00111: val_acc did not improve from 0.88260
# 196/196 [==============================] - 34s 171ms/step - loss: 0.2806 - acc: 0.8997 - val_loss: 0.4147 - val_acc: 0.8722
# Epoch 112/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2853 - acc: 0.8981
# Epoch 00112: val_acc did not improve from 0.88260
# 196/196 [==============================] - 34s 171ms/step - loss: 0.2851 - acc: 0.8981 - val_loss: 0.4339 - val_acc: 0.8703
# Epoch 113/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2827 - acc: 0.9004
# Epoch 00113: val_acc did not improve from 0.88260
# 196/196 [==============================] - 34s 172ms/step - loss: 0.2829 - acc: 0.9002 - val_loss: 0.3942 - val_acc: 0.8790
# Epoch 114/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2833 - acc: 0.8993
# Epoch 00114: val_acc did not improve from 0.88260
# 196/196 [==============================] - 34s 171ms/step - loss: 0.2836 - acc: 0.8992 - val_loss: 0.4014 - val_acc: 0.8770
# Epoch 115/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2820 - acc: 0.9019
# Epoch 00115: val_acc did not improve from 0.88260
# 196/196 [==============================] - 33s 171ms/step - loss: 0.2825 - acc: 0.9017 - val_loss: 0.4171 - val_acc: 0.8718
# Epoch 116/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2797 - acc: 0.8990
# Epoch 00116: val_acc did not improve from 0.88260
# 196/196 [==============================] - 34s 171ms/step - loss: 0.2797 - acc: 0.8990 - val_loss: 0.4879 - val_acc: 0.8538
# Epoch 117/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2762 - acc: 0.9016
# Epoch 00117: val_acc improved from 0.88260 to 0.88350, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 34s 172ms/step - loss: 0.2761 - acc: 0.9017 - val_loss: 0.3753 - val_acc: 0.8835
# Epoch 118/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2778 - acc: 0.9020
# Epoch 00118: val_acc did not improve from 0.88350
# 196/196 [==============================] - 34s 171ms/step - loss: 0.2781 - acc: 0.9019 - val_loss: 0.4177 - val_acc: 0.8739
# Epoch 119/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2717 - acc: 0.9028
# Epoch 00119: val_acc did not improve from 0.88350
# 196/196 [==============================] - 34s 171ms/step - loss: 0.2721 - acc: 0.9027 - val_loss: 0.4044 - val_acc: 0.8763
# Epoch 120/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2736 - acc: 0.9027
# Epoch 00120: val_acc did not improve from 0.88350
# 196/196 [==============================] - 33s 171ms/step - loss: 0.2735 - acc: 0.9028 - val_loss: 0.4145 - val_acc: 0.8746
# Epoch 121/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2727 - acc: 0.9027
# Epoch 00121: val_acc did not improve from 0.88350
# 196/196 [==============================] - 33s 171ms/step - loss: 0.2730 - acc: 0.9026 - val_loss: 0.4198 - val_acc: 0.8722
# Epoch 122/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2745 - acc: 0.9025
# Epoch 00122: val_acc did not improve from 0.88350
# 196/196 [==============================] - 34s 172ms/step - loss: 0.2744 - acc: 0.9025 - val_loss: 0.4221 - val_acc: 0.8710
# Epoch 123/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2713 - acc: 0.9026
# Epoch 00123: val_acc did not improve from 0.88350
# 196/196 [==============================] - 33s 171ms/step - loss: 0.2715 - acc: 0.9025 - val_loss: 0.4102 - val_acc: 0.8786
# Epoch 124/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2685 - acc: 0.9046
# Epoch 00124: val_acc improved from 0.88350 to 0.88520, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 34s 171ms/step - loss: 0.2682 - acc: 0.9047 - val_loss: 0.3874 - val_acc: 0.8852
# Epoch 125/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2681 - acc: 0.9034
# Epoch 00125: val_acc did not improve from 0.88520
# 196/196 [==============================] - 34s 172ms/step - loss: 0.2683 - acc: 0.9033 - val_loss: 0.4100 - val_acc: 0.8763
# Epoch 126/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2688 - acc: 0.9039
# Epoch 00126: val_acc did not improve from 0.88520
# 196/196 [==============================] - 34s 171ms/step - loss: 0.2688 - acc: 0.9040 - val_loss: 0.4386 - val_acc: 0.8681
# Epoch 127/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2657 - acc: 0.9048
# Epoch 00127: val_acc did not improve from 0.88520
# 196/196 [==============================] - 34s 172ms/step - loss: 0.2651 - acc: 0.9051 - val_loss: 0.3759 - val_acc: 0.8848
# Epoch 128/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2656 - acc: 0.9042
# Epoch 00128: val_acc did not improve from 0.88520
# 196/196 [==============================] - 34s 171ms/step - loss: 0.2657 - acc: 0.9041 - val_loss: 0.3983 - val_acc: 0.8811
# Epoch 129/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2649 - acc: 0.9048
# Epoch 00129: val_acc did not improve from 0.88520
# 196/196 [==============================] - 34s 171ms/step - loss: 0.2653 - acc: 0.9046 - val_loss: 0.4071 - val_acc: 0.8798
# Epoch 130/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2671 - acc: 0.9035
# Epoch 00130: val_acc did not improve from 0.88520
# 196/196 [==============================] - 34s 171ms/step - loss: 0.2673 - acc: 0.9033 - val_loss: 0.4222 - val_acc: 0.8729
# Epoch 131/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2639 - acc: 0.9042
# Epoch 00131: val_acc did not improve from 0.88520
# 196/196 [==============================] - 34s 171ms/step - loss: 0.2636 - acc: 0.9043 - val_loss: 0.4340 - val_acc: 0.8725
# Epoch 132/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2629 - acc: 0.9058
# Epoch 00132: val_acc did not improve from 0.88520
#
# Epoch 00132: ReduceLROnPlateau reducing learning rate to 0.25.
# 196/196 [==============================] - 34s 171ms/step - loss: 0.2627 - acc: 0.9059 - val_loss: 0.3944 - val_acc: 0.8785
# Epoch 133/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2457 - acc: 0.9102
# Epoch 00133: val_acc did not improve from 0.88520
# 196/196 [==============================] - 34s 171ms/step - loss: 0.2454 - acc: 0.9104 - val_loss: 0.4136 - val_acc: 0.8757
# Epoch 134/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2425 - acc: 0.9127
# Epoch 00134: val_acc improved from 0.88520 to 0.88770, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 33s 170ms/step - loss: 0.2427 - acc: 0.9125 - val_loss: 0.3709 - val_acc: 0.8877
# Epoch 135/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2394 - acc: 0.9137
# Epoch 00135: val_acc did not improve from 0.88770
# 196/196 [==============================] - 33s 169ms/step - loss: 0.2397 - acc: 0.9136 - val_loss: 0.4204 - val_acc: 0.8772
# Epoch 136/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2401 - acc: 0.9132
# Epoch 00136: val_acc did not improve from 0.88770
# 196/196 [==============================] - 34s 171ms/step - loss: 0.2399 - acc: 0.9133 - val_loss: 0.4395 - val_acc: 0.8747
# Epoch 137/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2366 - acc: 0.9153
# Epoch 00137: val_acc did not improve from 0.88770
# 196/196 [==============================] - 34s 172ms/step - loss: 0.2366 - acc: 0.9153 - val_loss: 0.3954 - val_acc: 0.8833
# Epoch 138/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2372 - acc: 0.9148
# Epoch 00138: val_acc did not improve from 0.88770
# 196/196 [==============================] - 34s 172ms/step - loss: 0.2372 - acc: 0.9148 - val_loss: 0.4078 - val_acc: 0.8808
# Epoch 139/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2416 - acc: 0.9130
# Epoch 00139: val_acc did not improve from 0.88770
# 196/196 [==============================] - 34s 171ms/step - loss: 0.2416 - acc: 0.9130 - val_loss: 0.4163 - val_acc: 0.8784
# Epoch 140/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2359 - acc: 0.9160
# Epoch 00140: val_acc did not improve from 0.88770
# 196/196 [==============================] - 34s 173ms/step - loss: 0.2357 - acc: 0.9159 - val_loss: 0.3920 - val_acc: 0.8845
# Epoch 141/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2382 - acc: 0.9147
# Epoch 00141: val_acc did not improve from 0.88770
# 196/196 [==============================] - 34s 175ms/step - loss: 0.2378 - acc: 0.9149 - val_loss: 0.3938 - val_acc: 0.8855
# Epoch 142/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2385 - acc: 0.9143
# Epoch 00142: val_acc did not improve from 0.88770
# 196/196 [==============================] - 33s 170ms/step - loss: 0.2386 - acc: 0.9143 - val_loss: 0.4101 - val_acc: 0.8780
# Epoch 143/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2342 - acc: 0.9150
# Epoch 00143: val_acc did not improve from 0.88770
# 196/196 [==============================] - 34s 173ms/step - loss: 0.2342 - acc: 0.9150 - val_loss: 0.4045 - val_acc: 0.8800
# Epoch 144/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2371 - acc: 0.9148
# Epoch 00144: val_acc improved from 0.88770 to 0.88800, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 34s 172ms/step - loss: 0.2367 - acc: 0.9150 - val_loss: 0.3793 - val_acc: 0.8880
# Epoch 145/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2339 - acc: 0.9152
# Epoch 00145: val_acc did not improve from 0.88800
# 196/196 [==============================] - 33s 169ms/step - loss: 0.2341 - acc: 0.9150 - val_loss: 0.3849 - val_acc: 0.8852
# Epoch 146/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2322 - acc: 0.9154
# Epoch 00146: val_acc did not improve from 0.88800
# 196/196 [==============================] - 34s 172ms/step - loss: 0.2323 - acc: 0.9154 - val_loss: 0.3932 - val_acc: 0.8836
# Epoch 147/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2293 - acc: 0.9168
# Epoch 00147: val_acc did not improve from 0.88800
# 196/196 [==============================] - 34s 172ms/step - loss: 0.2296 - acc: 0.9167 - val_loss: 0.4100 - val_acc: 0.8800
# Epoch 148/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2292 - acc: 0.9179
# Epoch 00148: val_acc did not improve from 0.88800
# 196/196 [==============================] - 33s 171ms/step - loss: 0.2294 - acc: 0.9178 - val_loss: 0.4187 - val_acc: 0.8787
# Epoch 149/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2335 - acc: 0.9158
# Epoch 00149: val_acc did not improve from 0.88800
#
# Epoch 00149: ReduceLROnPlateau reducing learning rate to 0.125.
# 196/196 [==============================] - 34s 171ms/step - loss: 0.2331 - acc: 0.9160 - val_loss: 0.3953 - val_acc: 0.8831
# Epoch 150/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2222 - acc: 0.9197
# Epoch 00150: val_acc did not improve from 0.88800
# 196/196 [==============================] - 34s 172ms/step - loss: 0.2225 - acc: 0.9195 - val_loss: 0.3886 - val_acc: 0.8870
# Epoch 151/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2263 - acc: 0.9174
# Epoch 00151: val_acc did not improve from 0.88800
# 196/196 [==============================] - 34s 173ms/step - loss: 0.2262 - acc: 0.9174 - val_loss: 0.3974 - val_acc: 0.8844
# Epoch 152/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2201 - acc: 0.9217
# Epoch 00152: val_acc did not improve from 0.88800
# 196/196 [==============================] - 34s 173ms/step - loss: 0.2203 - acc: 0.9215 - val_loss: 0.3960 - val_acc: 0.8825
# Epoch 153/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2206 - acc: 0.9201
# Epoch 00153: val_acc did not improve from 0.88800
# 196/196 [==============================] - 33s 171ms/step - loss: 0.2206 - acc: 0.9202 - val_loss: 0.4040 - val_acc: 0.8817
# Epoch 154/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2222 - acc: 0.9195
# Epoch 00154: val_acc did not improve from 0.88800
# 196/196 [==============================] - 33s 170ms/step - loss: 0.2220 - acc: 0.9197 - val_loss: 0.3910 - val_acc: 0.8841
# Epoch 155/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2157 - acc: 0.9208
# Epoch 00155: val_acc did not improve from 0.88800
# 196/196 [==============================] - 33s 170ms/step - loss: 0.2160 - acc: 0.9208 - val_loss: 0.3824 - val_acc: 0.8871
# Epoch 156/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2214 - acc: 0.9202
# Epoch 00156: val_acc improved from 0.88800 to 0.88920, saving model to day_1.weights.best.hdf5
# 196/196 [==============================] - 34s 172ms/step - loss: 0.2218 - acc: 0.9201 - val_loss: 0.3792 - val_acc: 0.8892
# Epoch 157/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2208 - acc: 0.9208
# Epoch 00157: val_acc did not improve from 0.88920
# 196/196 [==============================] - 35s 177ms/step - loss: 0.2205 - acc: 0.9209 - val_loss: 0.3833 - val_acc: 0.8868
# Epoch 158/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2208 - acc: 0.9206
# Epoch 00158: val_acc did not improve from 0.88920
# 196/196 [==============================] - 34s 173ms/step - loss: 0.2206 - acc: 0.9206 - val_loss: 0.3845 - val_acc: 0.8880
# Epoch 159/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2165 - acc: 0.9217
# Epoch 00159: val_acc did not improve from 0.88920
# 196/196 [==============================] - 34s 175ms/step - loss: 0.2169 - acc: 0.9216 - val_loss: 0.3907 - val_acc: 0.8845
# Epoch 160/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2203 - acc: 0.9202
# Epoch 00160: val_acc did not improve from 0.88920
# 196/196 [==============================] - 33s 171ms/step - loss: 0.2202 - acc: 0.9202 - val_loss: 0.4128 - val_acc: 0.8805
# Epoch 161/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2165 - acc: 0.9213
# Epoch 00161: val_acc did not improve from 0.88920
# 196/196 [==============================] - 34s 173ms/step - loss: 0.2167 - acc: 0.9212 - val_loss: 0.3957 - val_acc: 0.8860
# Epoch 162/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2182 - acc: 0.9215
# Epoch 00162: val_acc did not improve from 0.88920
# 196/196 [==============================] - 33s 171ms/step - loss: 0.2182 - acc: 0.9215 - val_loss: 0.4043 - val_acc: 0.8835
# Epoch 163/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2169 - acc: 0.9210
# Epoch 00163: val_acc did not improve from 0.88920
# 196/196 [==============================] - 34s 175ms/step - loss: 0.2173 - acc: 0.9208 - val_loss: 0.4056 - val_acc: 0.8831
# Epoch 164/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2176 - acc: 0.9219
# Epoch 00164: val_acc did not improve from 0.88920
#
# Epoch 00164: ReduceLROnPlateau reducing learning rate to 0.0625.
# 196/196 [==============================] - 35s 176ms/step - loss: 0.2177 - acc: 0.9218 - val_loss: 0.4057 - val_acc: 0.8831
# Epoch 165/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2106 - acc: 0.9234
# Epoch 00165: val_acc did not improve from 0.88920
# 196/196 [==============================] - 34s 172ms/step - loss: 0.2105 - acc: 0.9235 - val_loss: 0.3887 - val_acc: 0.8873
# Epoch 166/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2163 - acc: 0.9224
# Epoch 00166: val_acc did not improve from 0.88920
# 196/196 [==============================] - 34s 174ms/step - loss: 0.2163 - acc: 0.9224 - val_loss: 0.3849 - val_acc: 0.8880
# Epoch 167/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2113 - acc: 0.9231
# Epoch 00167: val_acc did not improve from 0.88920
# 196/196 [==============================] - 34s 172ms/step - loss: 0.2115 - acc: 0.9230 - val_loss: 0.3945 - val_acc: 0.8867
# Epoch 168/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2126 - acc: 0.9241
# Epoch 00168: val_acc did not improve from 0.88920
# 196/196 [==============================] - 34s 173ms/step - loss: 0.2126 - acc: 0.9241 - val_loss: 0.3947 - val_acc: 0.8865
# Epoch 169/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2114 - acc: 0.9240
# Epoch 00169: val_acc did not improve from 0.88920
# 196/196 [==============================] - 34s 173ms/step - loss: 0.2111 - acc: 0.9241 - val_loss: 0.3874 - val_acc: 0.8871
# Epoch 170/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.2108 - acc: 0.9243
# Epoch 00170: val_acc did not improve from 0.88920
# ...
# Epoch 00916: val_acc did not improve from 0.89180
# 196/196 [==============================] - 35s 181ms/step - loss: 0.1887 - acc: 0.9312 - val_loss: 0.3930 - val_acc: 0.8904
# Epoch 917/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.1842 - acc: 0.9331
# Epoch 00917: val_acc did not improve from 0.89180
# 196/196 [==============================] - 35s 179ms/step - loss: 0.1845 - acc: 0.9330 - val_loss: 0.3938 - val_acc: 0.8898
# Epoch 918/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.1872 - acc: 0.9329
# Epoch 00918: val_acc did not improve from 0.89180
# 196/196 [==============================] - 35s 179ms/step - loss: 0.1873 - acc: 0.9328 - val_loss: 0.3946 - val_acc: 0.8906
# Epoch 919/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.1862 - acc: 0.9330
# Epoch 00919: val_acc did not improve from 0.89180
# 196/196 [==============================] - 35s 179ms/step - loss: 0.1863 - acc: 0.9330 - val_loss: 0.3951 - val_acc: 0.8899
# Epoch 920/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.1849 - acc: 0.9325
# Epoch 00920: val_acc did not improve from 0.89180
# 196/196 [==============================] - 35s 178ms/step - loss: 0.1847 - acc: 0.9325 - val_loss: 0.3943 - val_acc: 0.8904
# Epoch 921/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.1834 - acc: 0.9326
# Epoch 00921: val_acc did not improve from 0.89180
# 196/196 [==============================] - 35s 178ms/step - loss: 0.1834 - acc: 0.9325 - val_loss: 0.3970 - val_acc: 0.8895
# Epoch 922/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.1867 - acc: 0.9330
# Epoch 00922: val_acc did not improve from 0.89180
# 196/196 [==============================] - 35s 179ms/step - loss: 0.1868 - acc: 0.9330 - val_loss: 0.3929 - val_acc: 0.8897
# Epoch 923/10000
# 195/196 [============================>.] - ETA: 0s - loss: 0.1851 - acc: 0.9332
# Epoch 00923: val_acc did not improve from 0.89180
# 196/196 [==============================] - 35s 180ms/step - loss: 0.1853 - acc: 0.9332 - val_loss: 0.3938 - val_acc: 0.8900
# Epoch 924/10000
# 146/196 [=====================>........] - ETA: 8s - loss: 0.1876 - acc: 0.9321
# Process ForkPoolWorker-22229:
# Process ForkPoolWorker-22233:
# Process ForkPoolWorker-22227:
# Process ForkPoolWorker-22232:
# Process ForkPoolWorker-22231:
# Process ForkPoolWorker-22238:
# Process ForkPoolWorker-22244:
# Traceback (most recent call last):
# Process ForkPoolWorker-22230:
# Traceback (most recent call last):
# Process ForkPoolWorker-22228:
# Process ForkPoolWorker-22240:
# Process ForkPoolWorker-22225:
# Process ForkPoolWorker-22226:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
# Traceback (most recent call last):
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
# KeyboardInterrupt
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/multiprocessing/queues.py", line 335, in get
#     res = self._reader.recv_bytes()
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/skyolia/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/site-packages/tensorflow/python/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     170         outs = model.train_on_batch(
# --> 171             x, y, sample_weight=sample_weight, class_weight=class_weight)
#     172
#
# ~/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1827       self._make_train_function()
# -> 1828       outputs = self.train_function(ins)
#    1829
#
# ~/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/site-packages/tensorflow/python/keras/backend.py in __call__(self, inputs)
#    2977     fetched = self._callable_fn(*array_vals,
# -> 2978                                 run_metadata=self.run_metadata)
#    2979     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#
# ~/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1398               self._session._session, self._handle, args, status,
# -> 1399               run_metadata_ptr)
#    1400         if run_metadata:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-e39cf098644d> in <module>
#      23                     shuffle=True,
#      24                     #initial_epoch=65,
# ---> 25                     callbacks=[checkpoint, reduce_lr, tblr])
#
# ~/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2063         use_multiprocessing=use_multiprocessing,
#    2064         shuffle=shuffle,
# -> 2065         initial_epoch=initial_epoch)
#    2066
#    2067   def evaluate_generator(self,
#
# ~/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/site-packages/tensorflow/python/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     217     try:
#     218       if enqueuer is not None:
# --> 219         enqueuer.stop()
#     220     finally:
#     221       if val_enqueuer is not None:
#
# ~/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/site-packages/tensorflow/python/keras/utils/data_utils.py in stop(self, timeout)
#     631       self.queue.unfinished_tasks = 0
#     632       self.queue.not_full.notify()
# --> 633     self.run_thread.join(timeout)
#     634     _SHARED_SEQUENCES[self.uid] = None
#     635
#
# ~/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/threading.py in join(self, timeout)
#    1054
#    1055         if timeout is None:
# -> 1056             self._wait_for_tstate_lock()
#    1057         else:
#    1058             # the behavior of a negative timeout isn't documented, but
#
# ~/anaconda3/envs/tensorflow_gpuenv/lib/python3.6/threading.py in _wait_for_tstate_lock(self, block, timeout)
#    1070         if lock is None:  # already determined that the C code is done
#    1071             assert self._is_stopped
# -> 1072         elif lock.acquire(block, timeout):
#    1073             lock.release()
#    1074             self._stop()
#
# KeyboardInterrupt:
